# %%
import numpy
import re
p = []
w = []
d = []
with open("dataPY.txt","r") as data:
    for n in range(10):
        s=(data.readline()).split()
        p.append(int(s[0]))
        w.append(int(s[1]))
        d.append(int(s[2]))

# %%
n=len(p)
N=1<<n
F=[0]
ListaL=[[]]
print(n)
print(N)
print(ListaL[0])
# Out:
# 10
# 1024
# []

# %%
for x in range(3):
    print(x)
# Out:
# 0
# 1
# 2

# %%
for set in range(1,N):
    sumaP=0
    b=1
    c=0
    #####zliczanie sumy####
    for j in range(n):
        if (set&b):
            c=c+p[j]
        b*=2
    ####DZIALA!!!!!###
    F.append(99999999)
    ListaL.append([])
    b=1
    for j in range(n):
        if (set&b):
            if (F[set]>F[set - b] + w[j] * max(c - d[j], 0)):
                pomocniczy=ListaL[set-b].copy()
                pomocniczy.append(j+1)
                ListaL[set]=pomocniczy.copy()
                F[set]=F[set - b] + w[j] * max(c - d[j], 0)
                print("Numer setu: ",set," Set: ",bin(set),"Kara: ",F[set])
                print("Poprzedni: ",ListaL[set-b])
                print("Po: ",ListaL[set])
        b=b*2
# Out:
# Numer setu:  1  Set:  0b1 Kara:  0
# Poprzedni:  []
# Po:  [1]
# Numer setu:  2  Set:  0b10 Kara:  0
# Poprzedni:  []
# Po:  [2]
# Numer setu:  3  Set:  0b11 Kara:  0
# Poprzedni:  [2]
# Po:  [2, 1]
# Numer setu:  4  Set:  0b100 Kara:  0
# Poprzedni:  []
# Po:  [3]
# Numer setu:  5  Set:  0b101 Kara:  0
# Poprzedni:  [3]
# Po:  [3, 1]
# Numer setu:  6  Set:  0b110 Kara:  0
# Poprzedni:  [3]
# Po:  [3, 2]
# Numer setu:  7  Set:  0b111 Kara:  0
# Poprzedni:  [3, 2]
# Po:  [3, 2, 1]
# Numer setu:  8  Set:  0b1000 Kara:  0
# Poprzedni:  []
# Po:  [4]
# Numer setu:  9  Set:  0b1001 Kara:  0
# Poprzedni:  [4]
# Po:  [4, 1]
# Numer setu:  10  Set:  0b1010 Kara:  0
# Poprzedni:  [4]
# Po:  [4, 2]
# Numer setu:  11  Set:  0b1011 Kara:  0
# Poprzedni:  [4, 2]
# Po:  [4, 2, 1]
# Numer setu:  12  Set:  0b1100 Kara:  0
# Poprzedni:  [4]
# Po:  [4, 3]
# Numer setu:  13  Set:  0b1101 Kara:  0
# Poprzedni:  [4, 3]
# Po:  [4, 3, 1]
# Numer setu:  14  Set:  0b1110 Kara:  0
# Poprzedni:  [4, 3]
# Po:  [4, 3, 2]
# Numer setu:  15  Set:  0b1111 Kara:  0
# Poprzedni:  [4, 3, 2]
# Po:  [4, 3, 2, 1]
# Numer setu:  16  Set:  0b10000 Kara:  31
# Poprzedni:  []
# Po:  [5]
# Numer setu:  17  Set:  0b10001 Kara:  31
# Poprzedni:  [5]
# Po:  [5, 1]
# Numer setu:  18  Set:  0b10010 Kara:  31
# Poprzedni:  [5]
# Po:  [5, 2]
# Numer setu:  19  Set:  0b10011 Kara:  31
# Poprzedni:  [5, 2]
# Po:  [5, 2, 1]
# Numer setu:  20  Set:  0b10100 Kara:  31
# Poprzedni:  [5]
# Po:  [5, 3]
# Numer setu:  21  Set:  0b10101 Kara:  31
# Poprzedni:  [5, 3]
# Po:  [5, 3, 1]
# Numer setu:  22  Set:  0b10110 Kara:  31
# Poprzedni:  [5, 3]
# Po:  [5, 3, 2]
# Numer setu:  23  Set:  0b10111 Kara:  31
# Poprzedni:  [5, 3, 2]
# Po:  [5, 3, 2, 1]
# Numer setu:  24  Set:  0b11000 Kara:  31
# Poprzedni:  [5]
# Po:  [5, 4]
# Numer setu:  25  Set:  0b11001 Kara:  31
# Poprzedni:  [5, 4]
# Po:  [5, 4, 1]
# Numer setu:  26  Set:  0b11010 Kara:  61
# Poprzedni:  [5, 4]
# Po:  [5, 4, 2]
# Numer setu:  26  Set:  0b11010 Kara:  31
# Poprzedni:  [5, 2]
# Po:  [5, 2, 4]
# Numer setu:  27  Set:  0b11011 Kara:  31
# Poprzedni:  [5, 2, 4]
# Po:  [5, 2, 4, 1]
# Numer setu:  28  Set:  0b11100 Kara:  31
# Poprzedni:  [5, 4]
# Po:  [5, 4, 3]
# Numer setu:  29  Set:  0b11101 Kara:  31
# Poprzedni:  [5, 4, 3]
# Po:  [5, 4, 3, 1]
# Numer setu:  30  Set:  0b11110 Kara:  86
# Poprzedni:  [5, 4, 3]
# Po:  [5, 4, 3, 2]
# Numer setu:  30  Set:  0b11110 Kara:  31
# Poprzedni:  [5, 2, 4]
# Po:  [5, 2, 4, 3]
# Numer setu:  31  Set:  0b11111 Kara:  31
# Poprzedni:  [5, 2, 4, 3]
# Po:  [5, 2, 4, 3, 1]
# Numer setu:  32  Set:  0b100000 Kara:  322
# Poprzedni:  []
# Po:  [6]
# Numer setu:  33  Set:  0b100001 Kara:  322
# Poprzedni:  [6]
# Po:  [6, 1]
# Numer setu:  34  Set:  0b100010 Kara:  322
# Poprzedni:  [6]
# Po:  [6, 2]
# Numer setu:  35  Set:  0b100011 Kara:  322
# Poprzedni:  [6, 2]
# Po:  [6, 2, 1]
# Numer setu:  36  Set:  0b100100 Kara:  322
# Poprzedni:  [6]
# Po:  [6, 3]
# Numer setu:  37  Set:  0b100101 Kara:  322
# Poprzedni:  [6, 3]
# Po:  [6, 3, 1]
# Numer setu:  38  Set:  0b100110 Kara:  322
# Poprzedni:  [6, 3]
# Po:  [6, 3, 2]
# Numer setu:  39  Set:  0b100111 Kara:  322
# Poprzedni:  [6, 3, 2]
# Po:  [6, 3, 2, 1]
# Numer setu:  40  Set:  0b101000 Kara:  322
# Poprzedni:  [6]
# Po:  [6, 4]
# Numer setu:  41  Set:  0b101001 Kara:  322
# Poprzedni:  [6, 4]
# Po:  [6, 4, 1]
# Numer setu:  42  Set:  0b101010 Kara:  322
# Poprzedni:  [6, 4]
# Po:  [6, 4, 2]
# Numer setu:  43  Set:  0b101011 Kara:  322
# Poprzedni:  [6, 4, 2]
# Po:  [6, 4, 2, 1]
# Numer setu:  44  Set:  0b101100 Kara:  322
# Poprzedni:  [6, 4]
# Po:  [6, 4, 3]
# Numer setu:  45  Set:  0b101101 Kara:  322
# Poprzedni:  [6, 4, 3]
# Po:  [6, 4, 3, 1]
# Numer setu:  46  Set:  0b101110 Kara:  322
# Poprzedni:  [6, 4, 3]
# Po:  [6, 4, 3, 2]
# Numer setu:  47  Set:  0b101111 Kara:  322
# Poprzedni:  [6, 4, 3, 2]
# Po:  [6, 4, 3, 2, 1]
# Numer setu:  48  Set:  0b110000 Kara:  406
# Poprzedni:  [6]
# Po:  [6, 5]
# Numer setu:  49  Set:  0b110001 Kara:  406
# Poprzedni:  [6, 5]
# Po:  [6, 5, 1]
# Numer setu:  50  Set:  0b110010 Kara:  406
# Poprzedni:  [6, 5]
# Po:  [6, 5, 2]
# Numer setu:  51  Set:  0b110011 Kara:  406
# Poprzedni:  [6, 5, 2]
# Po:  [6, 5, 2, 1]
# Numer setu:  52  Set:  0b110100 Kara:  406
# Poprzedni:  [6, 5]
# Po:  [6, 5, 3]
# Numer setu:  53  Set:  0b110101 Kara:  406
# Poprzedni:  [6, 5, 3]
# Po:  [6, 5, 3, 1]
# Numer setu:  54  Set:  0b110110 Kara:  406
# Poprzedni:  [6, 5, 3]
# Po:  [6, 5, 3, 2]
# Numer setu:  55  Set:  0b110111 Kara:  406
# Poprzedni:  [6, 5, 3, 2]
# Po:  [6, 5, 3, 2, 1]
# Numer setu:  56  Set:  0b111000 Kara:  406
# Poprzedni:  [6, 5]
# Po:  [6, 5, 4]
# Numer setu:  57  Set:  0b111001 Kara:  406
# Poprzedni:  [6, 5, 4]
# Po:  [6, 5, 4, 1]
# Numer setu:  58  Set:  0b111010 Kara:  701
# Poprzedni:  [6, 5, 4]
# Po:  [6, 5, 4, 2]
# Numer setu:  58  Set:  0b111010 Kara:  406
# Poprzedni:  [6, 5, 2]
# Po:  [6, 5, 2, 4]
# Numer setu:  59  Set:  0b111011 Kara:  406
# Poprzedni:  [6, 5, 2, 4]
# Po:  [6, 5, 2, 4, 1]
# Numer setu:  60  Set:  0b111100 Kara:  406
# Poprzedni:  [6, 5, 4]
# Po:  [6, 5, 4, 3]
# Numer setu:  61  Set:  0b111101 Kara:  406
# Poprzedni:  [6, 5, 4, 3]
# Po:  [6, 5, 4, 3, 1]
# Numer setu:  62  Set:  0b111110 Kara:  726
# Poprzedni:  [6, 5, 4, 3]
# Po:  [6, 5, 4, 3, 2]
# Numer setu:  62  Set:  0b111110 Kara:  406
# Poprzedni:  [6, 5, 2, 4]
# Po:  [6, 5, 2, 4, 3]
# Numer setu:  63  Set:  0b111111 Kara:  406
# Poprzedni:  [6, 5, 2, 4, 3]
# Po:  [6, 5, 2, 4, 3, 1]
# Numer setu:  64  Set:  0b1000000 Kara:  0
# Poprzedni:  []
# Po:  [7]
# Numer setu:  65  Set:  0b1000001 Kara:  0
# Poprzedni:  [7]
# Po:  [7, 1]
# Numer setu:  66  Set:  0b1000010 Kara:  0
# Poprzedni:  [7]
# Po:  [7, 2]
# Numer setu:  67  Set:  0b1000011 Kara:  0
# Poprzedni:  [7, 2]
# Po:  [7, 2, 1]
# Numer setu:  68  Set:  0b1000100 Kara:  0
# Poprzedni:  [7]
# Po:  [7, 3]
# Numer setu:  69  Set:  0b1000101 Kara:  0
# Poprzedni:  [7, 3]
# Po:  [7, 3, 1]
# Numer setu:  70  Set:  0b1000110 Kara:  0
# Poprzedni:  [7, 3]
# Po:  [7, 3, 2]
# Numer setu:  71  Set:  0b1000111 Kara:  0
# Poprzedni:  [7, 3, 2]
# Po:  [7, 3, 2, 1]
# Numer setu:  72  Set:  0b1001000 Kara:  0
# Poprzedni:  [7]
# Po:  [7, 4]
# Numer setu:  73  Set:  0b1001001 Kara:  0
# Poprzedni:  [7, 4]
# Po:  [7, 4, 1]
# Numer setu:  74  Set:  0b1001010 Kara:  0
# Poprzedni:  [7, 4]
# Po:  [7, 4, 2]
# Numer setu:  75  Set:  0b1001011 Kara:  0
# Poprzedni:  [7, 4, 2]
# Po:  [7, 4, 2, 1]
# Numer setu:  76  Set:  0b1001100 Kara:  0
# Poprzedni:  [7, 4]
# Po:  [7, 4, 3]
# Numer setu:  77  Set:  0b1001101 Kara:  0
# Poprzedni:  [7, 4, 3]
# Po:  [7, 4, 3, 1]
# Numer setu:  78  Set:  0b1001110 Kara:  0
# Poprzedni:  [7, 4, 3]
# Po:  [7, 4, 3, 2]
# Numer setu:  79  Set:  0b1001111 Kara:  0
# Poprzedni:  [7, 4, 3, 2]
# Po:  [7, 4, 3, 2, 1]
# Numer setu:  80  Set:  0b1010000 Kara:  69
# Poprzedni:  [7]
# Po:  [7, 5]
# Numer setu:  80  Set:  0b1010000 Kara:  31
# Poprzedni:  [5]
# Po:  [5, 7]
# Numer setu:  81  Set:  0b1010001 Kara:  31
# Poprzedni:  [5, 7]
# Po:  [5, 7, 1]
# Numer setu:  82  Set:  0b1010010 Kara:  31
# Poprzedni:  [5, 7]
# Po:  [5, 7, 2]
# Numer setu:  83  Set:  0b1010011 Kara:  31
# Poprzedni:  [5, 7, 2]
# Po:  [5, 7, 2, 1]
# Numer setu:  84  Set:  0b1010100 Kara:  31
# Poprzedni:  [5, 7]
# Po:  [5, 7, 3]
# Numer setu:  85  Set:  0b1010101 Kara:  31
# Poprzedni:  [5, 7, 3]
# Po:  [5, 7, 3, 1]
# Numer setu:  86  Set:  0b1010110 Kara:  31
# Poprzedni:  [5, 7, 3]
# Po:  [5, 7, 3, 2]
# Numer setu:  87  Set:  0b1010111 Kara:  31
# Poprzedni:  [5, 7, 3, 2]
# Po:  [5, 7, 3, 2, 1]
# Numer setu:  88  Set:  0b1011000 Kara:  31
# Poprzedni:  [5, 7]
# Po:  [5, 7, 4]
# Numer setu:  89  Set:  0b1011001 Kara:  31
# Poprzedni:  [5, 7, 4]
# Po:  [5, 7, 4, 1]
# Numer setu:  90  Set:  0b1011010 Kara:  251
# Poprzedni:  [5, 7, 4]
# Po:  [5, 7, 4, 2]
# Numer setu:  90  Set:  0b1011010 Kara:  31
# Poprzedni:  [5, 7, 2]
# Po:  [5, 7, 2, 4]
# Numer setu:  91  Set:  0b1011011 Kara:  31
# Poprzedni:  [5, 7, 2, 4]
# Po:  [5, 7, 2, 4, 1]
# Numer setu:  92  Set:  0b1011100 Kara:  31
# Poprzedni:  [5, 7, 4]
# Po:  [5, 7, 4, 3]
# Numer setu:  93  Set:  0b1011101 Kara:  31
# Poprzedni:  [5, 7, 4, 3]
# Po:  [5, 7, 4, 3, 1]
# Numer setu:  94  Set:  0b1011110 Kara:  276
# Poprzedni:  [5, 7, 4, 3]
# Po:  [5, 7, 4, 3, 2]
# Numer setu:  94  Set:  0b1011110 Kara:  31
# Poprzedni:  [5, 7, 2, 4]
# Po:  [5, 7, 2, 4, 3]
# Numer setu:  95  Set:  0b1011111 Kara:  31
# Poprzedni:  [5, 7, 2, 4, 3]
# Po:  [5, 7, 2, 4, 3, 1]
# Numer setu:  96  Set:  0b1100000 Kara:  588
# Poprzedni:  [7]
# Po:  [7, 6]
# Numer setu:  96  Set:  0b1100000 Kara:  322
# Poprzedni:  [6]
# Po:  [6, 7]
# Numer setu:  97  Set:  0b1100001 Kara:  322
# Poprzedni:  [6, 7]
# Po:  [6, 7, 1]
# Numer setu:  98  Set:  0b1100010 Kara:  322
# Poprzedni:  [6, 7]
# Po:  [6, 7, 2]
# Numer setu:  99  Set:  0b1100011 Kara:  322
# Poprzedni:  [6, 7, 2]
# Po:  [6, 7, 2, 1]
# Numer setu:  100  Set:  0b1100100 Kara:  322
# Poprzedni:  [6, 7]
# Po:  [6, 7, 3]
# Numer setu:  101  Set:  0b1100101 Kara:  322
# Poprzedni:  [6, 7, 3]
# Po:  [6, 7, 3, 1]
# Numer setu:  102  Set:  0b1100110 Kara:  322
# Poprzedni:  [6, 7, 3]
# Po:  [6, 7, 3, 2]
# Numer setu:  103  Set:  0b1100111 Kara:  322
# Poprzedni:  [6, 7, 3, 2]
# Po:  [6, 7, 3, 2, 1]
# Numer setu:  104  Set:  0b1101000 Kara:  322
# Poprzedni:  [6, 7]
# Po:  [6, 7, 4]
# Numer setu:  105  Set:  0b1101001 Kara:  322
# Poprzedni:  [6, 7, 4]
# Po:  [6, 7, 4, 1]
# Numer setu:  106  Set:  0b1101010 Kara:  392
# Poprzedni:  [6, 7, 4]
# Po:  [6, 7, 4, 2]
# Numer setu:  106  Set:  0b1101010 Kara:  322
# Poprzedni:  [6, 7, 2]
# Po:  [6, 7, 2, 4]
# Numer setu:  107  Set:  0b1101011 Kara:  322
# Poprzedni:  [6, 7, 2, 4]
# Po:  [6, 7, 2, 4, 1]
# Numer setu:  108  Set:  0b1101100 Kara:  322
# Poprzedni:  [6, 7, 4]
# Po:  [6, 7, 4, 3]
# Numer setu:  109  Set:  0b1101101 Kara:  322
# Poprzedni:  [6, 7, 4, 3]
# Po:  [6, 7, 4, 3, 1]
# Numer setu:  110  Set:  0b1101110 Kara:  417
# Poprzedni:  [6, 7, 4, 3]
# Po:  [6, 7, 4, 3, 2]
# Numer setu:  110  Set:  0b1101110 Kara:  322
# Poprzedni:  [6, 7, 2, 4]
# Po:  [6, 7, 2, 4, 3]
# Numer setu:  111  Set:  0b1101111 Kara:  322
# Poprzedni:  [6, 7, 2, 4, 3]
# Po:  [6, 7, 2, 4, 3, 1]
# Numer setu:  112  Set:  0b1110000 Kara:  444
# Poprzedni:  [6, 7]
# Po:  [6, 7, 5]
# Numer setu:  112  Set:  0b1110000 Kara:  406
# Poprzedni:  [6, 5]
# Po:  [6, 5, 7]
# Numer setu:  113  Set:  0b1110001 Kara:  406
# Poprzedni:  [6, 5, 7]
# Po:  [6, 5, 7, 1]
# Numer setu:  114  Set:  0b1110010 Kara:  426
# Poprzedni:  [6, 5, 7]
# Po:  [6, 5, 7, 2]
# Numer setu:  114  Set:  0b1110010 Kara:  406
# Poprzedni:  [6, 5, 2]
# Po:  [6, 5, 2, 7]
# Numer setu:  115  Set:  0b1110011 Kara:  406
# Poprzedni:  [6, 5, 2, 7]
# Po:  [6, 5, 2, 7, 1]
# Numer setu:  116  Set:  0b1110100 Kara:  406
# Poprzedni:  [6, 5, 7]
# Po:  [6, 5, 7, 3]
# Numer setu:  117  Set:  0b1110101 Kara:  406
# Poprzedni:  [6, 5, 7, 3]
# Po:  [6, 5, 7, 3, 1]
# Numer setu:  118  Set:  0b1110110 Kara:  451
# Poprzedni:  [6, 5, 7, 3]
# Po:  [6, 5, 7, 3, 2]
# Numer setu:  118  Set:  0b1110110 Kara:  406
# Poprzedni:  [6, 5, 2, 7]
# Po:  [6, 5, 2, 7, 3]
# Numer setu:  119  Set:  0b1110111 Kara:  406
# Poprzedni:  [6, 5, 2, 7, 3]
# Po:  [6, 5, 2, 7, 3, 1]
# Numer setu:  120  Set:  0b1111000 Kara:  406
# Poprzedni:  [6, 5, 7]
# Po:  [6, 5, 7, 4]
# Numer setu:  121  Set:  0b1111001 Kara:  406
# Poprzedni:  [6, 5, 7, 4]
# Po:  [6, 5, 7, 4, 1]
# Numer setu:  122  Set:  0b1111010 Kara:  891
# Poprzedni:  [6, 5, 7, 4]
# Po:  [6, 5, 7, 4, 2]
# Numer setu:  122  Set:  0b1111010 Kara:  406
# Poprzedni:  [6, 5, 2, 7]
# Po:  [6, 5, 2, 7, 4]
# Numer setu:  123  Set:  0b1111011 Kara:  406
# Poprzedni:  [6, 5, 2, 7, 4]
# Po:  [6, 5, 2, 7, 4, 1]
# Numer setu:  124  Set:  0b1111100 Kara:  406
# Poprzedni:  [6, 5, 7, 4]
# Po:  [6, 5, 7, 4, 3]
# Numer setu:  125  Set:  0b1111101 Kara:  406
# Poprzedni:  [6, 5, 7, 4, 3]
# Po:  [6, 5, 7, 4, 3, 1]
# Numer setu:  126  Set:  0b1111110 Kara:  916
# Poprzedni:  [6, 5, 7, 4, 3]
# Po:  [6, 5, 7, 4, 3, 2]
# Numer setu:  126  Set:  0b1111110 Kara:  406
# Poprzedni:  [6, 5, 2, 7, 4]
# Po:  [6, 5, 2, 7, 4, 3]
# Numer setu:  127  Set:  0b1111111 Kara:  406
# Poprzedni:  [6, 5, 2, 7, 4, 3]
# Po:  [6, 5, 2, 7, 4, 3, 1]
# Numer setu:  128  Set:  0b10000000 Kara:  0
# Poprzedni:  []
# Po:  [8]
# Numer setu:  129  Set:  0b10000001 Kara:  0
# Poprzedni:  [8]
# Po:  [8, 1]
# Numer setu:  130  Set:  0b10000010 Kara:  0
# Poprzedni:  [8]
# Po:  [8, 2]
# Numer setu:  131  Set:  0b10000011 Kara:  0
# Poprzedni:  [8, 2]
# Po:  [8, 2, 1]
# Numer setu:  132  Set:  0b10000100 Kara:  0
# Poprzedni:  [8]
# Po:  [8, 3]
# Numer setu:  133  Set:  0b10000101 Kara:  0
# Poprzedni:  [8, 3]
# Po:  [8, 3, 1]
# Numer setu:  134  Set:  0b10000110 Kara:  0
# Poprzedni:  [8, 3]
# Po:  [8, 3, 2]
# Numer setu:  135  Set:  0b10000111 Kara:  0
# Poprzedni:  [8, 3, 2]
# Po:  [8, 3, 2, 1]
# Numer setu:  136  Set:  0b10001000 Kara:  0
# Poprzedni:  [8]
# Po:  [8, 4]
# Numer setu:  137  Set:  0b10001001 Kara:  0
# Poprzedni:  [8, 4]
# Po:  [8, 4, 1]
# Numer setu:  138  Set:  0b10001010 Kara:  0
# Poprzedni:  [8, 4]
# Po:  [8, 4, 2]
# Numer setu:  139  Set:  0b10001011 Kara:  0
# Poprzedni:  [8, 4, 2]
# Po:  [8, 4, 2, 1]
# Numer setu:  140  Set:  0b10001100 Kara:  0
# Poprzedni:  [8, 4]
# Po:  [8, 4, 3]
# Numer setu:  141  Set:  0b10001101 Kara:  0
# Poprzedni:  [8, 4, 3]
# Po:  [8, 4, 3, 1]
# Numer setu:  142  Set:  0b10001110 Kara:  0
# Poprzedni:  [8, 4, 3]
# Po:  [8, 4, 3, 2]
# Numer setu:  143  Set:  0b10001111 Kara:  0
# Poprzedni:  [8, 4, 3, 2]
# Po:  [8, 4, 3, 2, 1]
# Numer setu:  144  Set:  0b10010000 Kara:  99
# Poprzedni:  [8]
# Po:  [8, 5]
# Numer setu:  144  Set:  0b10010000 Kara:  31
# Poprzedni:  [5]
# Po:  [5, 8]
# Numer setu:  145  Set:  0b10010001 Kara:  31
# Poprzedni:  [5, 8]
# Po:  [5, 8, 1]
# Numer setu:  146  Set:  0b10010010 Kara:  31
# Poprzedni:  [5, 8]
# Po:  [5, 8, 2]
# Numer setu:  147  Set:  0b10010011 Kara:  31
# Poprzedni:  [5, 8, 2]
# Po:  [5, 8, 2, 1]
# Numer setu:  148  Set:  0b10010100 Kara:  31
# Poprzedni:  [5, 8]
# Po:  [5, 8, 3]
# Numer setu:  149  Set:  0b10010101 Kara:  31
# Poprzedni:  [5, 8, 3]
# Po:  [5, 8, 3, 1]
# Numer setu:  150  Set:  0b10010110 Kara:  31
# Poprzedni:  [5, 8, 3]
# Po:  [5, 8, 3, 2]
# Numer setu:  151  Set:  0b10010111 Kara:  31
# Poprzedni:  [5, 8, 3, 2]
# Po:  [5, 8, 3, 2, 1]
# Numer setu:  152  Set:  0b10011000 Kara:  31
# Poprzedni:  [5, 8]
# Po:  [5, 8, 4]
# Numer setu:  153  Set:  0b10011001 Kara:  31
# Poprzedni:  [5, 8, 4]
# Po:  [5, 8, 4, 1]
# Numer setu:  154  Set:  0b10011010 Kara:  401
# Poprzedni:  [5, 8, 4]
# Po:  [5, 8, 4, 2]
# Numer setu:  154  Set:  0b10011010 Kara:  31
# Poprzedni:  [5, 8, 2]
# Po:  [5, 8, 2, 4]
# Numer setu:  155  Set:  0b10011011 Kara:  31
# Poprzedni:  [5, 8, 2, 4]
# Po:  [5, 8, 2, 4, 1]
# Numer setu:  156  Set:  0b10011100 Kara:  31
# Poprzedni:  [5, 8, 4]
# Po:  [5, 8, 4, 3]
# Numer setu:  157  Set:  0b10011101 Kara:  31
# Poprzedni:  [5, 8, 4, 3]
# Po:  [5, 8, 4, 3, 1]
# Numer setu:  158  Set:  0b10011110 Kara:  426
# Poprzedni:  [5, 8, 4, 3]
# Po:  [5, 8, 4, 3, 2]
# Numer setu:  158  Set:  0b10011110 Kara:  31
# Poprzedni:  [5, 8, 2, 4]
# Po:  [5, 8, 2, 4, 3]
# Numer setu:  159  Set:  0b10011111 Kara:  31
# Poprzedni:  [5, 8, 2, 4, 3]
# Po:  [5, 8, 2, 4, 3, 1]
# Numer setu:  160  Set:  0b10100000 Kara:  798
# Poprzedni:  [8]
# Po:  [8, 6]
# Numer setu:  160  Set:  0b10100000 Kara:  322
# Poprzedni:  [6]
# Po:  [6, 8]
# Numer setu:  161  Set:  0b10100001 Kara:  322
# Poprzedni:  [6, 8]
# Po:  [6, 8, 1]
# Numer setu:  162  Set:  0b10100010 Kara:  322
# Poprzedni:  [6, 8]
# Po:  [6, 8, 2]
# Numer setu:  163  Set:  0b10100011 Kara:  322
# Poprzedni:  [6, 8, 2]
# Po:  [6, 8, 2, 1]
# Numer setu:  164  Set:  0b10100100 Kara:  322
# Poprzedni:  [6, 8]
# Po:  [6, 8, 3]
# Numer setu:  165  Set:  0b10100101 Kara:  322
# Poprzedni:  [6, 8, 3]
# Po:  [6, 8, 3, 1]
# Numer setu:  166  Set:  0b10100110 Kara:  322
# Poprzedni:  [6, 8, 3]
# Po:  [6, 8, 3, 2]
# Numer setu:  167  Set:  0b10100111 Kara:  322
# Poprzedni:  [6, 8, 3, 2]
# Po:  [6, 8, 3, 2, 1]
# Numer setu:  168  Set:  0b10101000 Kara:  322
# Poprzedni:  [6, 8]
# Po:  [6, 8, 4]
# Numer setu:  169  Set:  0b10101001 Kara:  322
# Poprzedni:  [6, 8, 4]
# Po:  [6, 8, 4, 1]
# Numer setu:  170  Set:  0b10101010 Kara:  542
# Poprzedni:  [6, 8, 4]
# Po:  [6, 8, 4, 2]
# Numer setu:  170  Set:  0b10101010 Kara:  322
# Poprzedni:  [6, 8, 2]
# Po:  [6, 8, 2, 4]
# Numer setu:  171  Set:  0b10101011 Kara:  322
# Poprzedni:  [6, 8, 2, 4]
# Po:  [6, 8, 2, 4, 1]
# Numer setu:  172  Set:  0b10101100 Kara:  322
# Poprzedni:  [6, 8, 4]
# Po:  [6, 8, 4, 3]
# Numer setu:  173  Set:  0b10101101 Kara:  322
# Poprzedni:  [6, 8, 4, 3]
# Po:  [6, 8, 4, 3, 1]
# Numer setu:  174  Set:  0b10101110 Kara:  567
# Poprzedni:  [6, 8, 4, 3]
# Po:  [6, 8, 4, 3, 2]
# Numer setu:  174  Set:  0b10101110 Kara:  322
# Poprzedni:  [6, 8, 2, 4]
# Po:  [6, 8, 2, 4, 3]
# Numer setu:  175  Set:  0b10101111 Kara:  322
# Poprzedni:  [6, 8, 2, 4, 3]
# Po:  [6, 8, 2, 4, 3, 1]
# Numer setu:  176  Set:  0b10110000 Kara:  474
# Poprzedni:  [6, 8]
# Po:  [6, 8, 5]
# Numer setu:  176  Set:  0b10110000 Kara:  406
# Poprzedni:  [6, 5]
# Po:  [6, 5, 8]
# Numer setu:  177  Set:  0b10110001 Kara:  406
# Poprzedni:  [6, 5, 8]
# Po:  [6, 5, 8, 1]
# Numer setu:  178  Set:  0b10110010 Kara:  576
# Poprzedni:  [6, 5, 8]
# Po:  [6, 5, 8, 2]
# Numer setu:  178  Set:  0b10110010 Kara:  520
# Poprzedni:  [6, 8, 2]
# Po:  [6, 8, 2, 5]
# Numer setu:  178  Set:  0b10110010 Kara:  406
# Poprzedni:  [6, 5, 2]
# Po:  [6, 5, 2, 8]
# Numer setu:  179  Set:  0b10110011 Kara:  406
# Poprzedni:  [6, 5, 2, 8]
# Po:  [6, 5, 2, 8, 1]
# Numer setu:  180  Set:  0b10110100 Kara:  406
# Poprzedni:  [6, 5, 8]
# Po:  [6, 5, 8, 3]
# Numer setu:  181  Set:  0b10110101 Kara:  406
# Poprzedni:  [6, 5, 8, 3]
# Po:  [6, 5, 8, 3, 1]
# Numer setu:  182  Set:  0b10110110 Kara:  601
# Poprzedni:  [6, 5, 8, 3]
# Po:  [6, 5, 8, 3, 2]
# Numer setu:  182  Set:  0b10110110 Kara:  406
# Poprzedni:  [6, 5, 2, 8]
# Po:  [6, 5, 2, 8, 3]
# Numer setu:  183  Set:  0b10110111 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 3]
# Po:  [6, 5, 2, 8, 3, 1]
# Numer setu:  184  Set:  0b10111000 Kara:  406
# Poprzedni:  [6, 5, 8]
# Po:  [6, 5, 8, 4]
# Numer setu:  185  Set:  0b10111001 Kara:  406
# Poprzedni:  [6, 5, 8, 4]
# Po:  [6, 5, 8, 4, 1]
# Numer setu:  186  Set:  0b10111010 Kara:  1041
# Poprzedni:  [6, 5, 8, 4]
# Po:  [6, 5, 8, 4, 2]
# Numer setu:  186  Set:  0b10111010 Kara:  406
# Poprzedni:  [6, 5, 2, 8]
# Po:  [6, 5, 2, 8, 4]
# Numer setu:  187  Set:  0b10111011 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 4]
# Po:  [6, 5, 2, 8, 4, 1]
# Numer setu:  188  Set:  0b10111100 Kara:  406
# Poprzedni:  [6, 5, 8, 4]
# Po:  [6, 5, 8, 4, 3]
# Numer setu:  189  Set:  0b10111101 Kara:  406
# Poprzedni:  [6, 5, 8, 4, 3]
# Po:  [6, 5, 8, 4, 3, 1]
# Numer setu:  190  Set:  0b10111110 Kara:  1066
# Poprzedni:  [6, 5, 8, 4, 3]
# Po:  [6, 5, 8, 4, 3, 2]
# Numer setu:  190  Set:  0b10111110 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 4]
# Po:  [6, 5, 2, 8, 4, 3]
# Numer setu:  191  Set:  0b10111111 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 4, 3]
# Po:  [6, 5, 2, 8, 4, 3, 1]
# Numer setu:  192  Set:  0b11000000 Kara:  0
# Poprzedni:  [8]
# Po:  [8, 7]
# Numer setu:  193  Set:  0b11000001 Kara:  0
# Poprzedni:  [8, 7]
# Po:  [8, 7, 1]
# Numer setu:  194  Set:  0b11000010 Kara:  0
# Poprzedni:  [8, 7]
# Po:  [8, 7, 2]
# Numer setu:  195  Set:  0b11000011 Kara:  0
# Poprzedni:  [8, 7, 2]
# Po:  [8, 7, 2, 1]
# Numer setu:  196  Set:  0b11000100 Kara:  0
# Poprzedni:  [8, 7]
# Po:  [8, 7, 3]
# Numer setu:  197  Set:  0b11000101 Kara:  0
# Poprzedni:  [8, 7, 3]
# Po:  [8, 7, 3, 1]
# Numer setu:  198  Set:  0b11000110 Kara:  0
# Poprzedni:  [8, 7, 3]
# Po:  [8, 7, 3, 2]
# Numer setu:  199  Set:  0b11000111 Kara:  0
# Poprzedni:  [8, 7, 3, 2]
# Po:  [8, 7, 3, 2, 1]
# Numer setu:  200  Set:  0b11001000 Kara:  0
# Poprzedni:  [8, 7]
# Po:  [8, 7, 4]
# Numer setu:  201  Set:  0b11001001 Kara:  0
# Poprzedni:  [8, 7, 4]
# Po:  [8, 7, 4, 1]
# Numer setu:  202  Set:  0b11001010 Kara:  145
# Poprzedni:  [8, 7, 4]
# Po:  [8, 7, 4, 2]
# Numer setu:  202  Set:  0b11001010 Kara:  0
# Poprzedni:  [8, 7, 2]
# Po:  [8, 7, 2, 4]
# Numer setu:  203  Set:  0b11001011 Kara:  0
# Poprzedni:  [8, 7, 2, 4]
# Po:  [8, 7, 2, 4, 1]
# Numer setu:  204  Set:  0b11001100 Kara:  0
# Poprzedni:  [8, 7, 4]
# Po:  [8, 7, 4, 3]
# Numer setu:  205  Set:  0b11001101 Kara:  0
# Poprzedni:  [8, 7, 4, 3]
# Po:  [8, 7, 4, 3, 1]
# Numer setu:  206  Set:  0b11001110 Kara:  170
# Poprzedni:  [8, 7, 4, 3]
# Po:  [8, 7, 4, 3, 2]
# Numer setu:  206  Set:  0b11001110 Kara:  0
# Poprzedni:  [8, 7, 2, 4]
# Po:  [8, 7, 2, 4, 3]
# Numer setu:  207  Set:  0b11001111 Kara:  0
# Poprzedni:  [8, 7, 2, 4, 3]
# Po:  [8, 7, 2, 4, 3, 1]
# Numer setu:  208  Set:  0b11010000 Kara:  137
# Poprzedni:  [8, 7]
# Po:  [8, 7, 5]
# Numer setu:  208  Set:  0b11010000 Kara:  31
# Poprzedni:  [5, 8]
# Po:  [5, 8, 7]
# Numer setu:  209  Set:  0b11010001 Kara:  31
# Poprzedni:  [5, 8, 7]
# Po:  [5, 8, 7, 1]
# Numer setu:  210  Set:  0b11010010 Kara:  126
# Poprzedni:  [5, 8, 7]
# Po:  [5, 8, 7, 2]
# Numer setu:  210  Set:  0b11010010 Kara:  31
# Poprzedni:  [5, 8, 2]
# Po:  [5, 8, 2, 7]
# Numer setu:  211  Set:  0b11010011 Kara:  31
# Poprzedni:  [5, 8, 2, 7]
# Po:  [5, 8, 2, 7, 1]
# Numer setu:  212  Set:  0b11010100 Kara:  31
# Poprzedni:  [5, 8, 7]
# Po:  [5, 8, 7, 3]
# Numer setu:  213  Set:  0b11010101 Kara:  31
# Poprzedni:  [5, 8, 7, 3]
# Po:  [5, 8, 7, 3, 1]
# Numer setu:  214  Set:  0b11010110 Kara:  151
# Poprzedni:  [5, 8, 7, 3]
# Po:  [5, 8, 7, 3, 2]
# Numer setu:  214  Set:  0b11010110 Kara:  31
# Poprzedni:  [5, 8, 2, 7]
# Po:  [5, 8, 2, 7, 3]
# Numer setu:  215  Set:  0b11010111 Kara:  31
# Poprzedni:  [5, 8, 2, 7, 3]
# Po:  [5, 8, 2, 7, 3, 1]
# Numer setu:  216  Set:  0b11011000 Kara:  31
# Poprzedni:  [5, 8, 7]
# Po:  [5, 8, 7, 4]
# Numer setu:  217  Set:  0b11011001 Kara:  31
# Poprzedni:  [5, 8, 7, 4]
# Po:  [5, 8, 7, 4, 1]
# Numer setu:  218  Set:  0b11011010 Kara:  591
# Poprzedni:  [5, 8, 7, 4]
# Po:  [5, 8, 7, 4, 2]
# Numer setu:  218  Set:  0b11011010 Kara:  31
# Poprzedni:  [5, 8, 2, 7]
# Po:  [5, 8, 2, 7, 4]
# Numer setu:  219  Set:  0b11011011 Kara:  31
# Poprzedni:  [5, 8, 2, 7, 4]
# Po:  [5, 8, 2, 7, 4, 1]
# Numer setu:  220  Set:  0b11011100 Kara:  31
# Poprzedni:  [5, 8, 7, 4]
# Po:  [5, 8, 7, 4, 3]
# Numer setu:  221  Set:  0b11011101 Kara:  31
# Poprzedni:  [5, 8, 7, 4, 3]
# Po:  [5, 8, 7, 4, 3, 1]
# Numer setu:  222  Set:  0b11011110 Kara:  616
# Poprzedni:  [5, 8, 7, 4, 3]
# Po:  [5, 8, 7, 4, 3, 2]
# Numer setu:  222  Set:  0b11011110 Kara:  31
# Poprzedni:  [5, 8, 2, 7, 4]
# Po:  [5, 8, 2, 7, 4, 3]
# Numer setu:  223  Set:  0b11011111 Kara:  31
# Poprzedni:  [5, 8, 2, 7, 4, 3]
# Po:  [5, 8, 2, 7, 4, 3, 1]
# Numer setu:  224  Set:  0b11100000 Kara:  1064
# Poprzedni:  [8, 7]
# Po:  [8, 7, 6]
# Numer setu:  224  Set:  0b11100000 Kara:  322
# Poprzedni:  [6, 8]
# Po:  [6, 8, 7]
# Numer setu:  225  Set:  0b11100001 Kara:  322
# Poprzedni:  [6, 8, 7]
# Po:  [6, 8, 7, 1]
# Numer setu:  226  Set:  0b11100010 Kara:  322
# Poprzedni:  [6, 8, 7]
# Po:  [6, 8, 7, 2]
# Numer setu:  227  Set:  0b11100011 Kara:  322
# Poprzedni:  [6, 8, 7, 2]
# Po:  [6, 8, 7, 2, 1]
# Numer setu:  228  Set:  0b11100100 Kara:  322
# Poprzedni:  [6, 8, 7]
# Po:  [6, 8, 7, 3]
# Numer setu:  229  Set:  0b11100101 Kara:  322
# Poprzedni:  [6, 8, 7, 3]
# Po:  [6, 8, 7, 3, 1]
# Numer setu:  230  Set:  0b11100110 Kara:  322
# Poprzedni:  [6, 8, 7, 3]
# Po:  [6, 8, 7, 3, 2]
# Numer setu:  231  Set:  0b11100111 Kara:  322
# Poprzedni:  [6, 8, 7, 3, 2]
# Po:  [6, 8, 7, 3, 2, 1]
# Numer setu:  232  Set:  0b11101000 Kara:  322
# Poprzedni:  [6, 8, 7]
# Po:  [6, 8, 7, 4]
# Numer setu:  233  Set:  0b11101001 Kara:  322
# Poprzedni:  [6, 8, 7, 4]
# Po:  [6, 8, 7, 4, 1]
# Numer setu:  234  Set:  0b11101010 Kara:  732
# Poprzedni:  [6, 8, 7, 4]
# Po:  [6, 8, 7, 4, 2]
# Numer setu:  234  Set:  0b11101010 Kara:  322
# Poprzedni:  [6, 8, 7, 2]
# Po:  [6, 8, 7, 2, 4]
# Numer setu:  235  Set:  0b11101011 Kara:  322
# Poprzedni:  [6, 8, 7, 2, 4]
# Po:  [6, 8, 7, 2, 4, 1]
# Numer setu:  236  Set:  0b11101100 Kara:  322
# Poprzedni:  [6, 8, 7, 4]
# Po:  [6, 8, 7, 4, 3]
# Numer setu:  237  Set:  0b11101101 Kara:  322
# Poprzedni:  [6, 8, 7, 4, 3]
# Po:  [6, 8, 7, 4, 3, 1]
# Numer setu:  238  Set:  0b11101110 Kara:  757
# Poprzedni:  [6, 8, 7, 4, 3]
# Po:  [6, 8, 7, 4, 3, 2]
# Numer setu:  238  Set:  0b11101110 Kara:  322
# Poprzedni:  [6, 8, 7, 2, 4]
# Po:  [6, 8, 7, 2, 4, 3]
# Numer setu:  239  Set:  0b11101111 Kara:  322
# Poprzedni:  [6, 8, 7, 2, 4, 3]
# Po:  [6, 8, 7, 2, 4, 3, 1]
# Numer setu:  240  Set:  0b11110000 Kara:  512
# Poprzedni:  [6, 8, 7]
# Po:  [6, 8, 7, 5]
# Numer setu:  240  Set:  0b11110000 Kara:  406
# Poprzedni:  [6, 5, 8]
# Po:  [6, 5, 8, 7]
# Numer setu:  241  Set:  0b11110001 Kara:  406
# Poprzedni:  [6, 5, 8, 7]
# Po:  [6, 5, 8, 7, 1]
# Numer setu:  242  Set:  0b11110010 Kara:  766
# Poprzedni:  [6, 5, 8, 7]
# Po:  [6, 5, 8, 7, 2]
# Numer setu:  242  Set:  0b11110010 Kara:  558
# Poprzedni:  [6, 8, 7, 2]
# Po:  [6, 8, 7, 2, 5]
# Numer setu:  242  Set:  0b11110010 Kara:  406
# Poprzedni:  [6, 5, 2, 8]
# Po:  [6, 5, 2, 8, 7]
# Numer setu:  243  Set:  0b11110011 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 7]
# Po:  [6, 5, 2, 8, 7, 1]
# Numer setu:  244  Set:  0b11110100 Kara:  406
# Poprzedni:  [6, 5, 8, 7]
# Po:  [6, 5, 8, 7, 3]
# Numer setu:  245  Set:  0b11110101 Kara:  406
# Poprzedni:  [6, 5, 8, 7, 3]
# Po:  [6, 5, 8, 7, 3, 1]
# Numer setu:  246  Set:  0b11110110 Kara:  791
# Poprzedni:  [6, 5, 8, 7, 3]
# Po:  [6, 5, 8, 7, 3, 2]
# Numer setu:  246  Set:  0b11110110 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 7]
# Po:  [6, 5, 2, 8, 7, 3]
# Numer setu:  247  Set:  0b11110111 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 7, 3]
# Po:  [6, 5, 2, 8, 7, 3, 1]
# Numer setu:  248  Set:  0b11111000 Kara:  406
# Poprzedni:  [6, 5, 8, 7]
# Po:  [6, 5, 8, 7, 4]
# Numer setu:  249  Set:  0b11111001 Kara:  406
# Poprzedni:  [6, 5, 8, 7, 4]
# Po:  [6, 5, 8, 7, 4, 1]
# Numer setu:  250  Set:  0b11111010 Kara:  1231
# Poprzedni:  [6, 5, 8, 7, 4]
# Po:  [6, 5, 8, 7, 4, 2]
# Numer setu:  250  Set:  0b11111010 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 7]
# Po:  [6, 5, 2, 8, 7, 4]
# Numer setu:  251  Set:  0b11111011 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 7, 4]
# Po:  [6, 5, 2, 8, 7, 4, 1]
# Numer setu:  252  Set:  0b11111100 Kara:  406
# Poprzedni:  [6, 5, 8, 7, 4]
# Po:  [6, 5, 8, 7, 4, 3]
# Numer setu:  253  Set:  0b11111101 Kara:  406
# Poprzedni:  [6, 5, 8, 7, 4, 3]
# Po:  [6, 5, 8, 7, 4, 3, 1]
# Numer setu:  254  Set:  0b11111110 Kara:  1256
# Poprzedni:  [6, 5, 8, 7, 4, 3]
# Po:  [6, 5, 8, 7, 4, 3, 2]
# Numer setu:  254  Set:  0b11111110 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 7, 4]
# Po:  [6, 5, 2, 8, 7, 4, 3]
# Numer setu:  255  Set:  0b11111111 Kara:  406
# Poprzedni:  [6, 5, 2, 8, 7, 4, 3]
# Po:  [6, 5, 2, 8, 7, 4, 3, 1]
# Numer setu:  256  Set:  0b100000000 Kara:  0
# Poprzedni:  []
# Po:  [9]
# Numer setu:  257  Set:  0b100000001 Kara:  0
# Poprzedni:  [9]
# Po:  [9, 1]
# Numer setu:  258  Set:  0b100000010 Kara:  0
# Poprzedni:  [9]
# Po:  [9, 2]
# Numer setu:  259  Set:  0b100000011 Kara:  0
# Poprzedni:  [9, 2]
# Po:  [9, 2, 1]
# Numer setu:  260  Set:  0b100000100 Kara:  0
# Poprzedni:  [9]
# Po:  [9, 3]
# Numer setu:  261  Set:  0b100000101 Kara:  0
# Poprzedni:  [9, 3]
# Po:  [9, 3, 1]
# Numer setu:  262  Set:  0b100000110 Kara:  0
# Poprzedni:  [9, 3]
# Po:  [9, 3, 2]
# Numer setu:  263  Set:  0b100000111 Kara:  0
# Poprzedni:  [9, 3, 2]
# Po:  [9, 3, 2, 1]
# Numer setu:  264  Set:  0b100001000 Kara:  0
# Poprzedni:  [9]
# Po:  [9, 4]
# Numer setu:  265  Set:  0b100001001 Kara:  0
# Poprzedni:  [9, 4]
# Po:  [9, 4, 1]
# Numer setu:  266  Set:  0b100001010 Kara:  35
# Poprzedni:  [9, 4]
# Po:  [9, 4, 2]
# Numer setu:  266  Set:  0b100001010 Kara:  0
# Poprzedni:  [9, 2]
# Po:  [9, 2, 4]
# Numer setu:  267  Set:  0b100001011 Kara:  0
# Poprzedni:  [9, 2, 4]
# Po:  [9, 2, 4, 1]
# Numer setu:  268  Set:  0b100001100 Kara:  0
# Poprzedni:  [9, 4]
# Po:  [9, 4, 3]
# Numer setu:  269  Set:  0b100001101 Kara:  0
# Poprzedni:  [9, 4, 3]
# Po:  [9, 4, 3, 1]
# Numer setu:  270  Set:  0b100001110 Kara:  60
# Poprzedni:  [9, 4, 3]
# Po:  [9, 4, 3, 2]
# Numer setu:  270  Set:  0b100001110 Kara:  0
# Poprzedni:  [9, 2, 4]
# Po:  [9, 2, 4, 3]
# Numer setu:  271  Set:  0b100001111 Kara:  0
# Poprzedni:  [9, 2, 4, 3]
# Po:  [9, 2, 4, 3, 1]
# Numer setu:  272  Set:  0b100010000 Kara:  115
# Poprzedni:  [9]
# Po:  [9, 5]
# Numer setu:  273  Set:  0b100010001 Kara:  115
# Poprzedni:  [9, 5]
# Po:  [9, 5, 1]
# Numer setu:  274  Set:  0b100010010 Kara:  115
# Poprzedni:  [9, 5]
# Po:  [9, 5, 2]
# Numer setu:  275  Set:  0b100010011 Kara:  115
# Poprzedni:  [9, 5, 2]
# Po:  [9, 5, 2, 1]
# Numer setu:  276  Set:  0b100010100 Kara:  115
# Poprzedni:  [9, 5]
# Po:  [9, 5, 3]
# Numer setu:  277  Set:  0b100010101 Kara:  115
# Poprzedni:  [9, 5, 3]
# Po:  [9, 5, 3, 1]
# Numer setu:  278  Set:  0b100010110 Kara:  125
# Poprzedni:  [9, 5, 3]
# Po:  [9, 5, 3, 2]
# Numer setu:  278  Set:  0b100010110 Kara:  115
# Poprzedni:  [9, 5, 2]
# Po:  [9, 5, 2, 3]
# Numer setu:  279  Set:  0b100010111 Kara:  115
# Poprzedni:  [9, 5, 2, 3]
# Po:  [9, 5, 2, 3, 1]
# Numer setu:  280  Set:  0b100011000 Kara:  115
# Poprzedni:  [9, 5]
# Po:  [9, 5, 4]
# Numer setu:  281  Set:  0b100011001 Kara:  115
# Poprzedni:  [9, 5, 4]
# Po:  [9, 5, 4, 1]
# Numer setu:  282  Set:  0b100011010 Kara:  565
# Poprzedni:  [9, 5, 4]
# Po:  [9, 5, 4, 2]
# Numer setu:  282  Set:  0b100011010 Kara:  115
# Poprzedni:  [9, 5, 2]
# Po:  [9, 5, 2, 4]
# Numer setu:  283  Set:  0b100011011 Kara:  115
# Poprzedni:  [9, 5, 2, 4]
# Po:  [9, 5, 2, 4, 1]
# Numer setu:  284  Set:  0b100011100 Kara:  115
# Poprzedni:  [9, 5, 4]
# Po:  [9, 5, 4, 3]
# Numer setu:  285  Set:  0b100011101 Kara:  115
# Poprzedni:  [9, 5, 4, 3]
# Po:  [9, 5, 4, 3, 1]
# Numer setu:  286  Set:  0b100011110 Kara:  590
# Poprzedni:  [9, 5, 4, 3]
# Po:  [9, 5, 4, 3, 2]
# Numer setu:  286  Set:  0b100011110 Kara:  115
# Poprzedni:  [9, 5, 2, 4]
# Po:  [9, 5, 2, 4, 3]
# Numer setu:  287  Set:  0b100011111 Kara:  115
# Poprzedni:  [9, 5, 2, 4, 3]
# Po:  [9, 5, 2, 4, 3, 1]
# Numer setu:  288  Set:  0b100100000 Kara:  910
# Poprzedni:  [9]
# Po:  [9, 6]
# Numer setu:  288  Set:  0b100100000 Kara:  552
# Poprzedni:  [6]
# Po:  [6, 9]
# Numer setu:  289  Set:  0b100100001 Kara:  552
# Poprzedni:  [6, 9]
# Po:  [6, 9, 1]
# Numer setu:  290  Set:  0b100100010 Kara:  552
# Poprzedni:  [6, 9]
# Po:  [6, 9, 2]
# Numer setu:  291  Set:  0b100100011 Kara:  552
# Poprzedni:  [6, 9, 2]
# Po:  [6, 9, 2, 1]
# Numer setu:  292  Set:  0b100100100 Kara:  552
# Poprzedni:  [6, 9]
# Po:  [6, 9, 3]
# Numer setu:  293  Set:  0b100100101 Kara:  552
# Poprzedni:  [6, 9, 3]
# Po:  [6, 9, 3, 1]
# Numer setu:  294  Set:  0b100100110 Kara:  552
# Poprzedni:  [6, 9, 3]
# Po:  [6, 9, 3, 2]
# Numer setu:  295  Set:  0b100100111 Kara:  552
# Poprzedni:  [6, 9, 3, 2]
# Po:  [6, 9, 3, 2, 1]
# Numer setu:  296  Set:  0b100101000 Kara:  552
# Poprzedni:  [6, 9]
# Po:  [6, 9, 4]
# Numer setu:  297  Set:  0b100101001 Kara:  552
# Poprzedni:  [6, 9, 4]
# Po:  [6, 9, 4, 1]
# Numer setu:  298  Set:  0b100101010 Kara:  852
# Poprzedni:  [6, 9, 4]
# Po:  [6, 9, 4, 2]
# Numer setu:  298  Set:  0b100101010 Kara:  552
# Poprzedni:  [6, 9, 2]
# Po:  [6, 9, 2, 4]
# Numer setu:  299  Set:  0b100101011 Kara:  552
# Poprzedni:  [6, 9, 2, 4]
# Po:  [6, 9, 2, 4, 1]
# Numer setu:  300  Set:  0b100101100 Kara:  552
# Poprzedni:  [6, 9, 4]
# Po:  [6, 9, 4, 3]
# Numer setu:  301  Set:  0b100101101 Kara:  552
# Poprzedni:  [6, 9, 4, 3]
# Po:  [6, 9, 4, 3, 1]
# Numer setu:  302  Set:  0b100101110 Kara:  877
# Poprzedni:  [6, 9, 4, 3]
# Po:  [6, 9, 4, 3, 2]
# Numer setu:  302  Set:  0b100101110 Kara:  552
# Poprzedni:  [6, 9, 2, 4]
# Po:  [6, 9, 2, 4, 3]
# Numer setu:  303  Set:  0b100101111 Kara:  552
# Poprzedni:  [6, 9, 2, 4, 3]
# Po:  [6, 9, 2, 4, 3, 1]
# Numer setu:  304  Set:  0b100110000 Kara:  720
# Poprzedni:  [6, 9]
# Po:  [6, 9, 5]
# Numer setu:  305  Set:  0b100110001 Kara:  720
# Poprzedni:  [6, 9, 5]
# Po:  [6, 9, 5, 1]
# Numer setu:  306  Set:  0b100110010 Kara:  970
# Poprzedni:  [6, 9, 5]
# Po:  [6, 9, 5, 2]
# Numer setu:  306  Set:  0b100110010 Kara:  766
# Poprzedni:  [6, 9, 2]
# Po:  [6, 9, 2, 5]
# Numer setu:  307  Set:  0b100110011 Kara:  766
# Poprzedni:  [6, 9, 2, 5]
# Po:  [6, 9, 2, 5, 1]
# Numer setu:  308  Set:  0b100110100 Kara:  720
# Poprzedni:  [6, 9, 5]
# Po:  [6, 9, 5, 3]
# Numer setu:  309  Set:  0b100110101 Kara:  720
# Poprzedni:  [6, 9, 5, 3]
# Po:  [6, 9, 5, 3, 1]
# Numer setu:  310  Set:  0b100110110 Kara:  995
# Poprzedni:  [6, 9, 5, 3]
# Po:  [6, 9, 5, 3, 2]
# Numer setu:  310  Set:  0b100110110 Kara:  766
# Poprzedni:  [6, 9, 2, 5]
# Po:  [6, 9, 2, 5, 3]
# Numer setu:  311  Set:  0b100110111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 3]
# Po:  [6, 9, 2, 5, 3, 1]
# Numer setu:  312  Set:  0b100111000 Kara:  720
# Poprzedni:  [6, 9, 5]
# Po:  [6, 9, 5, 4]
# Numer setu:  313  Set:  0b100111001 Kara:  720
# Poprzedni:  [6, 9, 5, 4]
# Po:  [6, 9, 5, 4, 1]
# Numer setu:  314  Set:  0b100111010 Kara:  1435
# Poprzedni:  [6, 9, 5, 4]
# Po:  [6, 9, 5, 4, 2]
# Numer setu:  314  Set:  0b100111010 Kara:  766
# Poprzedni:  [6, 9, 2, 5]
# Po:  [6, 9, 2, 5, 4]
# Numer setu:  315  Set:  0b100111011 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 4]
# Po:  [6, 9, 2, 5, 4, 1]
# Numer setu:  316  Set:  0b100111100 Kara:  720
# Poprzedni:  [6, 9, 5, 4]
# Po:  [6, 9, 5, 4, 3]
# Numer setu:  317  Set:  0b100111101 Kara:  720
# Poprzedni:  [6, 9, 5, 4, 3]
# Po:  [6, 9, 5, 4, 3, 1]
# Numer setu:  318  Set:  0b100111110 Kara:  1460
# Poprzedni:  [6, 9, 5, 4, 3]
# Po:  [6, 9, 5, 4, 3, 2]
# Numer setu:  318  Set:  0b100111110 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 4]
# Po:  [6, 9, 2, 5, 4, 3]
# Numer setu:  319  Set:  0b100111111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 4, 3]
# Po:  [6, 9, 2, 5, 4, 3, 1]
# Numer setu:  320  Set:  0b101000000 Kara:  0
# Poprzedni:  [9]
# Po:  [9, 7]
# Numer setu:  321  Set:  0b101000001 Kara:  0
# Poprzedni:  [9, 7]
# Po:  [9, 7, 1]
# Numer setu:  322  Set:  0b101000010 Kara:  0
# Poprzedni:  [9, 7]
# Po:  [9, 7, 2]
# Numer setu:  323  Set:  0b101000011 Kara:  0
# Poprzedni:  [9, 7, 2]
# Po:  [9, 7, 2, 1]
# Numer setu:  324  Set:  0b101000100 Kara:  0
# Poprzedni:  [9, 7]
# Po:  [9, 7, 3]
# Numer setu:  325  Set:  0b101000101 Kara:  0
# Poprzedni:  [9, 7, 3]
# Po:  [9, 7, 3, 1]
# Numer setu:  326  Set:  0b101000110 Kara:  0
# Poprzedni:  [9, 7, 3]
# Po:  [9, 7, 3, 2]
# Numer setu:  327  Set:  0b101000111 Kara:  0
# Poprzedni:  [9, 7, 3, 2]
# Po:  [9, 7, 3, 2, 1]
# Numer setu:  328  Set:  0b101001000 Kara:  0
# Poprzedni:  [9, 7]
# Po:  [9, 7, 4]
# Numer setu:  329  Set:  0b101001001 Kara:  0
# Poprzedni:  [9, 7, 4]
# Po:  [9, 7, 4, 1]
# Numer setu:  330  Set:  0b101001010 Kara:  225
# Poprzedni:  [9, 7, 4]
# Po:  [9, 7, 4, 2]
# Numer setu:  330  Set:  0b101001010 Kara:  0
# Poprzedni:  [9, 7, 2]
# Po:  [9, 7, 2, 4]
# Numer setu:  331  Set:  0b101001011 Kara:  0
# Poprzedni:  [9, 7, 2, 4]
# Po:  [9, 7, 2, 4, 1]
# Numer setu:  332  Set:  0b101001100 Kara:  0
# Poprzedni:  [9, 7, 4]
# Po:  [9, 7, 4, 3]
# Numer setu:  333  Set:  0b101001101 Kara:  0
# Poprzedni:  [9, 7, 4, 3]
# Po:  [9, 7, 4, 3, 1]
# Numer setu:  334  Set:  0b101001110 Kara:  250
# Poprzedni:  [9, 7, 4, 3]
# Po:  [9, 7, 4, 3, 2]
# Numer setu:  334  Set:  0b101001110 Kara:  0
# Poprzedni:  [9, 7, 2, 4]
# Po:  [9, 7, 2, 4, 3]
# Numer setu:  335  Set:  0b101001111 Kara:  0
# Poprzedni:  [9, 7, 2, 4, 3]
# Po:  [9, 7, 2, 4, 3, 1]
# Numer setu:  336  Set:  0b101010000 Kara:  153
# Poprzedni:  [9, 7]
# Po:  [9, 7, 5]
# Numer setu:  336  Set:  0b101010000 Kara:  115
# Poprzedni:  [9, 5]
# Po:  [9, 5, 7]
# Numer setu:  337  Set:  0b101010001 Kara:  115
# Poprzedni:  [9, 5, 7]
# Po:  [9, 5, 7, 1]
# Numer setu:  338  Set:  0b101010010 Kara:  290
# Poprzedni:  [9, 5, 7]
# Po:  [9, 5, 7, 2]
# Numer setu:  338  Set:  0b101010010 Kara:  199
# Poprzedni:  [9, 7, 2]
# Po:  [9, 7, 2, 5]
# Numer setu:  338  Set:  0b101010010 Kara:  115
# Poprzedni:  [9, 5, 2]
# Po:  [9, 5, 2, 7]
# Numer setu:  339  Set:  0b101010011 Kara:  115
# Poprzedni:  [9, 5, 2, 7]
# Po:  [9, 5, 2, 7, 1]
# Numer setu:  340  Set:  0b101010100 Kara:  115
# Poprzedni:  [9, 5, 7]
# Po:  [9, 5, 7, 3]
# Numer setu:  341  Set:  0b101010101 Kara:  115
# Poprzedni:  [9, 5, 7, 3]
# Po:  [9, 5, 7, 3, 1]
# Numer setu:  342  Set:  0b101010110 Kara:  315
# Poprzedni:  [9, 5, 7, 3]
# Po:  [9, 5, 7, 3, 2]
# Numer setu:  342  Set:  0b101010110 Kara:  115
# Poprzedni:  [9, 5, 2, 7]
# Po:  [9, 5, 2, 7, 3]
# Numer setu:  343  Set:  0b101010111 Kara:  115
# Poprzedni:  [9, 5, 2, 7, 3]
# Po:  [9, 5, 2, 7, 3, 1]
# Numer setu:  344  Set:  0b101011000 Kara:  115
# Poprzedni:  [9, 5, 7]
# Po:  [9, 5, 7, 4]
# Numer setu:  345  Set:  0b101011001 Kara:  115
# Poprzedni:  [9, 5, 7, 4]
# Po:  [9, 5, 7, 4, 1]
# Numer setu:  346  Set:  0b101011010 Kara:  755
# Poprzedni:  [9, 5, 7, 4]
# Po:  [9, 5, 7, 4, 2]
# Numer setu:  346  Set:  0b101011010 Kara:  115
# Poprzedni:  [9, 5, 2, 7]
# Po:  [9, 5, 2, 7, 4]
# Numer setu:  347  Set:  0b101011011 Kara:  115
# Poprzedni:  [9, 5, 2, 7, 4]
# Po:  [9, 5, 2, 7, 4, 1]
# Numer setu:  348  Set:  0b101011100 Kara:  115
# Poprzedni:  [9, 5, 7, 4]
# Po:  [9, 5, 7, 4, 3]
# Numer setu:  349  Set:  0b101011101 Kara:  115
# Poprzedni:  [9, 5, 7, 4, 3]
# Po:  [9, 5, 7, 4, 3, 1]
# Numer setu:  350  Set:  0b101011110 Kara:  780
# Poprzedni:  [9, 5, 7, 4, 3]
# Po:  [9, 5, 7, 4, 3, 2]
# Numer setu:  350  Set:  0b101011110 Kara:  115
# Poprzedni:  [9, 5, 2, 7, 4]
# Po:  [9, 5, 2, 7, 4, 3]
# Numer setu:  351  Set:  0b101011111 Kara:  115
# Poprzedni:  [9, 5, 2, 7, 4, 3]
# Po:  [9, 5, 2, 7, 4, 3, 1]
# Numer setu:  352  Set:  0b101100000 Kara:  1176
# Poprzedni:  [9, 7]
# Po:  [9, 7, 6]
# Numer setu:  352  Set:  0b101100000 Kara:  552
# Poprzedni:  [6, 9]
# Po:  [6, 9, 7]
# Numer setu:  353  Set:  0b101100001 Kara:  552
# Poprzedni:  [6, 9, 7]
# Po:  [6, 9, 7, 1]
# Numer setu:  354  Set:  0b101100010 Kara:  577
# Poprzedni:  [6, 9, 7]
# Po:  [6, 9, 7, 2]
# Numer setu:  354  Set:  0b101100010 Kara:  552
# Poprzedni:  [6, 9, 2]
# Po:  [6, 9, 2, 7]
# Numer setu:  355  Set:  0b101100011 Kara:  552
# Poprzedni:  [6, 9, 2, 7]
# Po:  [6, 9, 2, 7, 1]
# Numer setu:  356  Set:  0b101100100 Kara:  552
# Poprzedni:  [6, 9, 7]
# Po:  [6, 9, 7, 3]
# Numer setu:  357  Set:  0b101100101 Kara:  552
# Poprzedni:  [6, 9, 7, 3]
# Po:  [6, 9, 7, 3, 1]
# Numer setu:  358  Set:  0b101100110 Kara:  602
# Poprzedni:  [6, 9, 7, 3]
# Po:  [6, 9, 7, 3, 2]
# Numer setu:  358  Set:  0b101100110 Kara:  552
# Poprzedni:  [6, 9, 2, 7]
# Po:  [6, 9, 2, 7, 3]
# Numer setu:  359  Set:  0b101100111 Kara:  552
# Poprzedni:  [6, 9, 2, 7, 3]
# Po:  [6, 9, 2, 7, 3, 1]
# Numer setu:  360  Set:  0b101101000 Kara:  552
# Poprzedni:  [6, 9, 7]
# Po:  [6, 9, 7, 4]
# Numer setu:  361  Set:  0b101101001 Kara:  552
# Poprzedni:  [6, 9, 7, 4]
# Po:  [6, 9, 7, 4, 1]
# Numer setu:  362  Set:  0b101101010 Kara:  1042
# Poprzedni:  [6, 9, 7, 4]
# Po:  [6, 9, 7, 4, 2]
# Numer setu:  362  Set:  0b101101010 Kara:  552
# Poprzedni:  [6, 9, 2, 7]
# Po:  [6, 9, 2, 7, 4]
# Numer setu:  363  Set:  0b101101011 Kara:  552
# Poprzedni:  [6, 9, 2, 7, 4]
# Po:  [6, 9, 2, 7, 4, 1]
# Numer setu:  364  Set:  0b101101100 Kara:  552
# Poprzedni:  [6, 9, 7, 4]
# Po:  [6, 9, 7, 4, 3]
# Numer setu:  365  Set:  0b101101101 Kara:  552
# Poprzedni:  [6, 9, 7, 4, 3]
# Po:  [6, 9, 7, 4, 3, 1]
# Numer setu:  366  Set:  0b101101110 Kara:  1067
# Poprzedni:  [6, 9, 7, 4, 3]
# Po:  [6, 9, 7, 4, 3, 2]
# Numer setu:  366  Set:  0b101101110 Kara:  552
# Poprzedni:  [6, 9, 2, 7, 4]
# Po:  [6, 9, 2, 7, 4, 3]
# Numer setu:  367  Set:  0b101101111 Kara:  552
# Poprzedni:  [6, 9, 2, 7, 4, 3]
# Po:  [6, 9, 2, 7, 4, 3, 1]
# Numer setu:  368  Set:  0b101110000 Kara:  758
# Poprzedni:  [6, 9, 7]
# Po:  [6, 9, 7, 5]
# Numer setu:  368  Set:  0b101110000 Kara:  720
# Poprzedni:  [6, 9, 5]
# Po:  [6, 9, 5, 7]
# Numer setu:  369  Set:  0b101110001 Kara:  720
# Poprzedni:  [6, 9, 5, 7]
# Po:  [6, 9, 5, 7, 1]
# Numer setu:  370  Set:  0b101110010 Kara:  1160
# Poprzedni:  [6, 9, 5, 7]
# Po:  [6, 9, 5, 7, 2]
# Numer setu:  370  Set:  0b101110010 Kara:  804
# Poprzedni:  [6, 9, 2, 7]
# Po:  [6, 9, 2, 7, 5]
# Numer setu:  370  Set:  0b101110010 Kara:  766
# Poprzedni:  [6, 9, 2, 5]
# Po:  [6, 9, 2, 5, 7]
# Numer setu:  371  Set:  0b101110011 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 7]
# Po:  [6, 9, 2, 5, 7, 1]
# Numer setu:  372  Set:  0b101110100 Kara:  720
# Poprzedni:  [6, 9, 5, 7]
# Po:  [6, 9, 5, 7, 3]
# Numer setu:  373  Set:  0b101110101 Kara:  720
# Poprzedni:  [6, 9, 5, 7, 3]
# Po:  [6, 9, 5, 7, 3, 1]
# Numer setu:  374  Set:  0b101110110 Kara:  1185
# Poprzedni:  [6, 9, 5, 7, 3]
# Po:  [6, 9, 5, 7, 3, 2]
# Numer setu:  374  Set:  0b101110110 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 7]
# Po:  [6, 9, 2, 5, 7, 3]
# Numer setu:  375  Set:  0b101110111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 7, 3]
# Po:  [6, 9, 2, 5, 7, 3, 1]
# Numer setu:  376  Set:  0b101111000 Kara:  720
# Poprzedni:  [6, 9, 5, 7]
# Po:  [6, 9, 5, 7, 4]
# Numer setu:  377  Set:  0b101111001 Kara:  720
# Poprzedni:  [6, 9, 5, 7, 4]
# Po:  [6, 9, 5, 7, 4, 1]
# Numer setu:  378  Set:  0b101111010 Kara:  1625
# Poprzedni:  [6, 9, 5, 7, 4]
# Po:  [6, 9, 5, 7, 4, 2]
# Numer setu:  378  Set:  0b101111010 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 7]
# Po:  [6, 9, 2, 5, 7, 4]
# Numer setu:  379  Set:  0b101111011 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 7, 4]
# Po:  [6, 9, 2, 5, 7, 4, 1]
# Numer setu:  380  Set:  0b101111100 Kara:  720
# Poprzedni:  [6, 9, 5, 7, 4]
# Po:  [6, 9, 5, 7, 4, 3]
# Numer setu:  381  Set:  0b101111101 Kara:  720
# Poprzedni:  [6, 9, 5, 7, 4, 3]
# Po:  [6, 9, 5, 7, 4, 3, 1]
# Numer setu:  382  Set:  0b101111110 Kara:  1650
# Poprzedni:  [6, 9, 5, 7, 4, 3]
# Po:  [6, 9, 5, 7, 4, 3, 2]
# Numer setu:  382  Set:  0b101111110 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 7, 4]
# Po:  [6, 9, 2, 5, 7, 4, 3]
# Numer setu:  383  Set:  0b101111111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 7, 4, 3]
# Po:  [6, 9, 2, 5, 7, 4, 3, 1]
# Numer setu:  384  Set:  0b110000000 Kara:  0
# Poprzedni:  [9]
# Po:  [9, 8]
# Numer setu:  385  Set:  0b110000001 Kara:  0
# Poprzedni:  [9, 8]
# Po:  [9, 8, 1]
# Numer setu:  386  Set:  0b110000010 Kara:  0
# Poprzedni:  [9, 8]
# Po:  [9, 8, 2]
# Numer setu:  387  Set:  0b110000011 Kara:  0
# Poprzedni:  [9, 8, 2]
# Po:  [9, 8, 2, 1]
# Numer setu:  388  Set:  0b110000100 Kara:  0
# Poprzedni:  [9, 8]
# Po:  [9, 8, 3]
# Numer setu:  389  Set:  0b110000101 Kara:  0
# Poprzedni:  [9, 8, 3]
# Po:  [9, 8, 3, 1]
# Numer setu:  390  Set:  0b110000110 Kara:  0
# Poprzedni:  [9, 8, 3]
# Po:  [9, 8, 3, 2]
# Numer setu:  391  Set:  0b110000111 Kara:  0
# Poprzedni:  [9, 8, 3, 2]
# Po:  [9, 8, 3, 2, 1]
# Numer setu:  392  Set:  0b110001000 Kara:  0
# Poprzedni:  [9, 8]
# Po:  [9, 8, 4]
# Numer setu:  393  Set:  0b110001001 Kara:  0
# Poprzedni:  [9, 8, 4]
# Po:  [9, 8, 4, 1]
# Numer setu:  394  Set:  0b110001010 Kara:  375
# Poprzedni:  [9, 8, 4]
# Po:  [9, 8, 4, 2]
# Numer setu:  394  Set:  0b110001010 Kara:  0
# Poprzedni:  [9, 8, 2]
# Po:  [9, 8, 2, 4]
# Numer setu:  395  Set:  0b110001011 Kara:  0
# Poprzedni:  [9, 8, 2, 4]
# Po:  [9, 8, 2, 4, 1]
# Numer setu:  396  Set:  0b110001100 Kara:  0
# Poprzedni:  [9, 8, 4]
# Po:  [9, 8, 4, 3]
# Numer setu:  397  Set:  0b110001101 Kara:  0
# Poprzedni:  [9, 8, 4, 3]
# Po:  [9, 8, 4, 3, 1]
# Numer setu:  398  Set:  0b110001110 Kara:  400
# Poprzedni:  [9, 8, 4, 3]
# Po:  [9, 8, 4, 3, 2]
# Numer setu:  398  Set:  0b110001110 Kara:  0
# Poprzedni:  [9, 8, 2, 4]
# Po:  [9, 8, 2, 4, 3]
# Numer setu:  399  Set:  0b110001111 Kara:  0
# Poprzedni:  [9, 8, 2, 4, 3]
# Po:  [9, 8, 2, 4, 3, 1]
# Numer setu:  400  Set:  0b110010000 Kara:  183
# Poprzedni:  [9, 8]
# Po:  [9, 8, 5]
# Numer setu:  400  Set:  0b110010000 Kara:  115
# Poprzedni:  [9, 5]
# Po:  [9, 5, 8]
# Numer setu:  401  Set:  0b110010001 Kara:  115
# Poprzedni:  [9, 5, 8]
# Po:  [9, 5, 8, 1]
# Numer setu:  402  Set:  0b110010010 Kara:  440
# Poprzedni:  [9, 5, 8]
# Po:  [9, 5, 8, 2]
# Numer setu:  402  Set:  0b110010010 Kara:  229
# Poprzedni:  [9, 8, 2]
# Po:  [9, 8, 2, 5]
# Numer setu:  402  Set:  0b110010010 Kara:  115
# Poprzedni:  [9, 5, 2]
# Po:  [9, 5, 2, 8]
# Numer setu:  403  Set:  0b110010011 Kara:  115
# Poprzedni:  [9, 5, 2, 8]
# Po:  [9, 5, 2, 8, 1]
# Numer setu:  404  Set:  0b110010100 Kara:  115
# Poprzedni:  [9, 5, 8]
# Po:  [9, 5, 8, 3]
# Numer setu:  405  Set:  0b110010101 Kara:  115
# Poprzedni:  [9, 5, 8, 3]
# Po:  [9, 5, 8, 3, 1]
# Numer setu:  406  Set:  0b110010110 Kara:  465
# Poprzedni:  [9, 5, 8, 3]
# Po:  [9, 5, 8, 3, 2]
# Numer setu:  406  Set:  0b110010110 Kara:  115
# Poprzedni:  [9, 5, 2, 8]
# Po:  [9, 5, 2, 8, 3]
# Numer setu:  407  Set:  0b110010111 Kara:  115
# Poprzedni:  [9, 5, 2, 8, 3]
# Po:  [9, 5, 2, 8, 3, 1]
# Numer setu:  408  Set:  0b110011000 Kara:  115
# Poprzedni:  [9, 5, 8]
# Po:  [9, 5, 8, 4]
# Numer setu:  409  Set:  0b110011001 Kara:  115
# Poprzedni:  [9, 5, 8, 4]
# Po:  [9, 5, 8, 4, 1]
# Numer setu:  410  Set:  0b110011010 Kara:  905
# Poprzedni:  [9, 5, 8, 4]
# Po:  [9, 5, 8, 4, 2]
# Numer setu:  410  Set:  0b110011010 Kara:  115
# Poprzedni:  [9, 5, 2, 8]
# Po:  [9, 5, 2, 8, 4]
# Numer setu:  411  Set:  0b110011011 Kara:  115
# Poprzedni:  [9, 5, 2, 8, 4]
# Po:  [9, 5, 2, 8, 4, 1]
# Numer setu:  412  Set:  0b110011100 Kara:  115
# Poprzedni:  [9, 5, 8, 4]
# Po:  [9, 5, 8, 4, 3]
# Numer setu:  413  Set:  0b110011101 Kara:  115
# Poprzedni:  [9, 5, 8, 4, 3]
# Po:  [9, 5, 8, 4, 3, 1]
# Numer setu:  414  Set:  0b110011110 Kara:  930
# Poprzedni:  [9, 5, 8, 4, 3]
# Po:  [9, 5, 8, 4, 3, 2]
# Numer setu:  414  Set:  0b110011110 Kara:  115
# Poprzedni:  [9, 5, 2, 8, 4]
# Po:  [9, 5, 2, 8, 4, 3]
# Numer setu:  415  Set:  0b110011111 Kara:  115
# Poprzedni:  [9, 5, 2, 8, 4, 3]
# Po:  [9, 5, 2, 8, 4, 3, 1]
# Numer setu:  416  Set:  0b110100000 Kara:  1386
# Poprzedni:  [9, 8]
# Po:  [9, 8, 6]
# Numer setu:  416  Set:  0b110100000 Kara:  552
# Poprzedni:  [6, 9]
# Po:  [6, 9, 8]
# Numer setu:  417  Set:  0b110100001 Kara:  552
# Poprzedni:  [6, 9, 8]
# Po:  [6, 9, 8, 1]
# Numer setu:  418  Set:  0b110100010 Kara:  727
# Poprzedni:  [6, 9, 8]
# Po:  [6, 9, 8, 2]
# Numer setu:  418  Set:  0b110100010 Kara:  552
# Poprzedni:  [6, 9, 2]
# Po:  [6, 9, 2, 8]
# Numer setu:  419  Set:  0b110100011 Kara:  552
# Poprzedni:  [6, 9, 2, 8]
# Po:  [6, 9, 2, 8, 1]
# Numer setu:  420  Set:  0b110100100 Kara:  552
# Poprzedni:  [6, 9, 8]
# Po:  [6, 9, 8, 3]
# Numer setu:  421  Set:  0b110100101 Kara:  552
# Poprzedni:  [6, 9, 8, 3]
# Po:  [6, 9, 8, 3, 1]
# Numer setu:  422  Set:  0b110100110 Kara:  752
# Poprzedni:  [6, 9, 8, 3]
# Po:  [6, 9, 8, 3, 2]
# Numer setu:  422  Set:  0b110100110 Kara:  552
# Poprzedni:  [6, 9, 2, 8]
# Po:  [6, 9, 2, 8, 3]
# Numer setu:  423  Set:  0b110100111 Kara:  552
# Poprzedni:  [6, 9, 2, 8, 3]
# Po:  [6, 9, 2, 8, 3, 1]
# Numer setu:  424  Set:  0b110101000 Kara:  552
# Poprzedni:  [6, 9, 8]
# Po:  [6, 9, 8, 4]
# Numer setu:  425  Set:  0b110101001 Kara:  552
# Poprzedni:  [6, 9, 8, 4]
# Po:  [6, 9, 8, 4, 1]
# Numer setu:  426  Set:  0b110101010 Kara:  1192
# Poprzedni:  [6, 9, 8, 4]
# Po:  [6, 9, 8, 4, 2]
# Numer setu:  426  Set:  0b110101010 Kara:  552
# Poprzedni:  [6, 9, 2, 8]
# Po:  [6, 9, 2, 8, 4]
# Numer setu:  427  Set:  0b110101011 Kara:  552
# Poprzedni:  [6, 9, 2, 8, 4]
# Po:  [6, 9, 2, 8, 4, 1]
# Numer setu:  428  Set:  0b110101100 Kara:  552
# Poprzedni:  [6, 9, 8, 4]
# Po:  [6, 9, 8, 4, 3]
# Numer setu:  429  Set:  0b110101101 Kara:  552
# Poprzedni:  [6, 9, 8, 4, 3]
# Po:  [6, 9, 8, 4, 3, 1]
# Numer setu:  430  Set:  0b110101110 Kara:  1217
# Poprzedni:  [6, 9, 8, 4, 3]
# Po:  [6, 9, 8, 4, 3, 2]
# Numer setu:  430  Set:  0b110101110 Kara:  552
# Poprzedni:  [6, 9, 2, 8, 4]
# Po:  [6, 9, 2, 8, 4, 3]
# Numer setu:  431  Set:  0b110101111 Kara:  552
# Poprzedni:  [6, 9, 2, 8, 4, 3]
# Po:  [6, 9, 2, 8, 4, 3, 1]
# Numer setu:  432  Set:  0b110110000 Kara:  788
# Poprzedni:  [6, 9, 8]
# Po:  [6, 9, 8, 5]
# Numer setu:  432  Set:  0b110110000 Kara:  720
# Poprzedni:  [6, 9, 5]
# Po:  [6, 9, 5, 8]
# Numer setu:  433  Set:  0b110110001 Kara:  720
# Poprzedni:  [6, 9, 5, 8]
# Po:  [6, 9, 5, 8, 1]
# Numer setu:  434  Set:  0b110110010 Kara:  1310
# Poprzedni:  [6, 9, 5, 8]
# Po:  [6, 9, 5, 8, 2]
# Numer setu:  434  Set:  0b110110010 Kara:  834
# Poprzedni:  [6, 9, 2, 8]
# Po:  [6, 9, 2, 8, 5]
# Numer setu:  434  Set:  0b110110010 Kara:  766
# Poprzedni:  [6, 9, 2, 5]
# Po:  [6, 9, 2, 5, 8]
# Numer setu:  435  Set:  0b110110011 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 8]
# Po:  [6, 9, 2, 5, 8, 1]
# Numer setu:  436  Set:  0b110110100 Kara:  720
# Poprzedni:  [6, 9, 5, 8]
# Po:  [6, 9, 5, 8, 3]
# Numer setu:  437  Set:  0b110110101 Kara:  720
# Poprzedni:  [6, 9, 5, 8, 3]
# Po:  [6, 9, 5, 8, 3, 1]
# Numer setu:  438  Set:  0b110110110 Kara:  1335
# Poprzedni:  [6, 9, 5, 8, 3]
# Po:  [6, 9, 5, 8, 3, 2]
# Numer setu:  438  Set:  0b110110110 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 8]
# Po:  [6, 9, 2, 5, 8, 3]
# Numer setu:  439  Set:  0b110110111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 8, 3]
# Po:  [6, 9, 2, 5, 8, 3, 1]
# Numer setu:  440  Set:  0b110111000 Kara:  720
# Poprzedni:  [6, 9, 5, 8]
# Po:  [6, 9, 5, 8, 4]
# Numer setu:  441  Set:  0b110111001 Kara:  720
# Poprzedni:  [6, 9, 5, 8, 4]
# Po:  [6, 9, 5, 8, 4, 1]
# Numer setu:  442  Set:  0b110111010 Kara:  1775
# Poprzedni:  [6, 9, 5, 8, 4]
# Po:  [6, 9, 5, 8, 4, 2]
# Numer setu:  442  Set:  0b110111010 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 8]
# Po:  [6, 9, 2, 5, 8, 4]
# Numer setu:  443  Set:  0b110111011 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 8, 4]
# Po:  [6, 9, 2, 5, 8, 4, 1]
# Numer setu:  444  Set:  0b110111100 Kara:  720
# Poprzedni:  [6, 9, 5, 8, 4]
# Po:  [6, 9, 5, 8, 4, 3]
# Numer setu:  445  Set:  0b110111101 Kara:  720
# Poprzedni:  [6, 9, 5, 8, 4, 3]
# Po:  [6, 9, 5, 8, 4, 3, 1]
# Numer setu:  446  Set:  0b110111110 Kara:  1800
# Poprzedni:  [6, 9, 5, 8, 4, 3]
# Po:  [6, 9, 5, 8, 4, 3, 2]
# Numer setu:  446  Set:  0b110111110 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 8, 4]
# Po:  [6, 9, 2, 5, 8, 4, 3]
# Numer setu:  447  Set:  0b110111111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 8, 4, 3]
# Po:  [6, 9, 2, 5, 8, 4, 3, 1]
# Numer setu:  448  Set:  0b111000000 Kara:  0
# Poprzedni:  [9, 8]
# Po:  [9, 8, 7]
# Numer setu:  449  Set:  0b111000001 Kara:  0
# Poprzedni:  [9, 8, 7]
# Po:  [9, 8, 7, 1]
# Numer setu:  450  Set:  0b111000010 Kara:  100
# Poprzedni:  [9, 8, 7]
# Po:  [9, 8, 7, 2]
# Numer setu:  450  Set:  0b111000010 Kara:  0
# Poprzedni:  [9, 8, 2]
# Po:  [9, 8, 2, 7]
# Numer setu:  451  Set:  0b111000011 Kara:  0
# Poprzedni:  [9, 8, 2, 7]
# Po:  [9, 8, 2, 7, 1]
# Numer setu:  452  Set:  0b111000100 Kara:  0
# Poprzedni:  [9, 8, 7]
# Po:  [9, 8, 7, 3]
# Numer setu:  453  Set:  0b111000101 Kara:  0
# Poprzedni:  [9, 8, 7, 3]
# Po:  [9, 8, 7, 3, 1]
# Numer setu:  454  Set:  0b111000110 Kara:  125
# Poprzedni:  [9, 8, 7, 3]
# Po:  [9, 8, 7, 3, 2]
# Numer setu:  454  Set:  0b111000110 Kara:  0
# Poprzedni:  [9, 8, 2, 7]
# Po:  [9, 8, 2, 7, 3]
# Numer setu:  455  Set:  0b111000111 Kara:  0
# ...
# Poprzedni:  [9, 5, 10]
# Po:  [9, 5, 10, 8]
# Numer setu:  913  Set:  0b1110010001 Kara:  115
# Poprzedni:  [9, 5, 10, 8]
# Po:  [9, 5, 10, 8, 1]
# Numer setu:  914  Set:  0b1110010010 Kara:  765
# Poprzedni:  [9, 5, 10, 8]
# Po:  [9, 5, 10, 8, 2]
# Numer setu:  914  Set:  0b1110010010 Kara:  294
# Poprzedni:  [9, 10, 2, 8]
# Po:  [9, 10, 2, 8, 5]
# Numer setu:  914  Set:  0b1110010010 Kara:  115
# Poprzedni:  [9, 5, 2, 10]
# Po:  [9, 5, 2, 10, 8]
# Numer setu:  915  Set:  0b1110010011 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8]
# Po:  [9, 5, 2, 10, 8, 1]
# Numer setu:  916  Set:  0b1110010100 Kara:  115
# Poprzedni:  [9, 5, 10, 8]
# Po:  [9, 5, 10, 8, 3]
# Numer setu:  917  Set:  0b1110010101 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 3]
# Po:  [9, 5, 10, 8, 3, 1]
# Numer setu:  918  Set:  0b1110010110 Kara:  790
# Poprzedni:  [9, 5, 10, 8, 3]
# Po:  [9, 5, 10, 8, 3, 2]
# Numer setu:  918  Set:  0b1110010110 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8]
# Po:  [9, 5, 2, 10, 8, 3]
# Numer setu:  919  Set:  0b1110010111 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 3]
# Po:  [9, 5, 2, 10, 8, 3, 1]
# Numer setu:  920  Set:  0b1110011000 Kara:  115
# Poprzedni:  [9, 5, 10, 8]
# Po:  [9, 5, 10, 8, 4]
# Numer setu:  921  Set:  0b1110011001 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 4]
# Po:  [9, 5, 10, 8, 4, 1]
# Numer setu:  922  Set:  0b1110011010 Kara:  1230
# Poprzedni:  [9, 5, 10, 8, 4]
# Po:  [9, 5, 10, 8, 4, 2]
# Numer setu:  922  Set:  0b1110011010 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8]
# Po:  [9, 5, 2, 10, 8, 4]
# Numer setu:  923  Set:  0b1110011011 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 4]
# Po:  [9, 5, 2, 10, 8, 4, 1]
# Numer setu:  924  Set:  0b1110011100 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 4]
# Po:  [9, 5, 10, 8, 4, 3]
# Numer setu:  925  Set:  0b1110011101 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 4, 3]
# Po:  [9, 5, 10, 8, 4, 3, 1]
# Numer setu:  926  Set:  0b1110011110 Kara:  1255
# Poprzedni:  [9, 5, 10, 8, 4, 3]
# Po:  [9, 5, 10, 8, 4, 3, 2]
# Numer setu:  926  Set:  0b1110011110 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 4]
# Po:  [9, 5, 2, 10, 8, 4, 3]
# Numer setu:  927  Set:  0b1110011111 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 4, 3]
# Po:  [9, 5, 2, 10, 8, 4, 3, 1]
# Numer setu:  928  Set:  0b1110100000 Kara:  1841
# Poprzedni:  [9, 10, 8]
# Po:  [9, 10, 8, 6]
# Numer setu:  928  Set:  0b1110100000 Kara:  552
# Poprzedni:  [6, 9, 10]
# Po:  [6, 9, 10, 8]
# Numer setu:  929  Set:  0b1110100001 Kara:  552
# Poprzedni:  [6, 9, 10, 8]
# Po:  [6, 9, 10, 8, 1]
# Numer setu:  930  Set:  0b1110100010 Kara:  1052
# Poprzedni:  [6, 9, 10, 8]
# Po:  [6, 9, 10, 8, 2]
# Numer setu:  930  Set:  0b1110100010 Kara:  552
# Poprzedni:  [6, 9, 2, 10]
# Po:  [6, 9, 2, 10, 8]
# Numer setu:  931  Set:  0b1110100011 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8]
# Po:  [6, 9, 2, 10, 8, 1]
# Numer setu:  932  Set:  0b1110100100 Kara:  552
# Poprzedni:  [6, 9, 10, 8]
# Po:  [6, 9, 10, 8, 3]
# Numer setu:  933  Set:  0b1110100101 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 3]
# Po:  [6, 9, 10, 8, 3, 1]
# Numer setu:  934  Set:  0b1110100110 Kara:  1077
# Poprzedni:  [6, 9, 10, 8, 3]
# Po:  [6, 9, 10, 8, 3, 2]
# Numer setu:  934  Set:  0b1110100110 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8]
# Po:  [6, 9, 2, 10, 8, 3]
# Numer setu:  935  Set:  0b1110100111 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 3]
# Po:  [6, 9, 2, 10, 8, 3, 1]
# Numer setu:  936  Set:  0b1110101000 Kara:  552
# Poprzedni:  [6, 9, 10, 8]
# Po:  [6, 9, 10, 8, 4]
# Numer setu:  937  Set:  0b1110101001 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 4]
# Po:  [6, 9, 10, 8, 4, 1]
# Numer setu:  938  Set:  0b1110101010 Kara:  1517
# Poprzedni:  [6, 9, 10, 8, 4]
# Po:  [6, 9, 10, 8, 4, 2]
# Numer setu:  938  Set:  0b1110101010 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8]
# Po:  [6, 9, 2, 10, 8, 4]
# Numer setu:  939  Set:  0b1110101011 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 4]
# Po:  [6, 9, 2, 10, 8, 4, 1]
# Numer setu:  940  Set:  0b1110101100 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 4]
# Po:  [6, 9, 10, 8, 4, 3]
# Numer setu:  941  Set:  0b1110101101 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 4, 3]
# Po:  [6, 9, 10, 8, 4, 3, 1]
# Numer setu:  942  Set:  0b1110101110 Kara:  1542
# Poprzedni:  [6, 9, 10, 8, 4, 3]
# Po:  [6, 9, 10, 8, 4, 3, 2]
# Numer setu:  942  Set:  0b1110101110 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 4]
# Po:  [6, 9, 2, 10, 8, 4, 3]
# Numer setu:  943  Set:  0b1110101111 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 4, 3]
# Po:  [6, 9, 2, 10, 8, 4, 3, 1]
# Numer setu:  944  Set:  0b1110110000 Kara:  853
# Poprzedni:  [6, 9, 10, 8]
# Po:  [6, 9, 10, 8, 5]
# Numer setu:  944  Set:  0b1110110000 Kara:  720
# Poprzedni:  [6, 9, 5, 10]
# Po:  [6, 9, 5, 10, 8]
# Numer setu:  945  Set:  0b1110110001 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8]
# Po:  [6, 9, 5, 10, 8, 1]
# Numer setu:  946  Set:  0b1110110010 Kara:  1635
# Poprzedni:  [6, 9, 5, 10, 8]
# Po:  [6, 9, 5, 10, 8, 2]
# Numer setu:  946  Set:  0b1110110010 Kara:  899
# Poprzedni:  [6, 9, 2, 10, 8]
# Po:  [6, 9, 2, 10, 8, 5]
# Numer setu:  946  Set:  0b1110110010 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10]
# Po:  [6, 9, 2, 5, 10, 8]
# Numer setu:  947  Set:  0b1110110011 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 8]
# Po:  [6, 9, 2, 5, 10, 8, 1]
# Numer setu:  948  Set:  0b1110110100 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8]
# Po:  [6, 9, 5, 10, 8, 3]
# Numer setu:  949  Set:  0b1110110101 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 3]
# Po:  [6, 9, 5, 10, 8, 3, 1]
# Numer setu:  950  Set:  0b1110110110 Kara:  1660
# Poprzedni:  [6, 9, 5, 10, 8, 3]
# Po:  [6, 9, 5, 10, 8, 3, 2]
# Numer setu:  950  Set:  0b1110110110 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 8]
# Po:  [6, 9, 2, 5, 10, 8, 3]
# Numer setu:  951  Set:  0b1110110111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 8, 3]
# Po:  [6, 9, 2, 5, 10, 8, 3, 1]
# Numer setu:  952  Set:  0b1110111000 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8]
# Po:  [6, 9, 5, 10, 8, 4]
# Numer setu:  953  Set:  0b1110111001 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 4]
# Po:  [6, 9, 5, 10, 8, 4, 1]
# Numer setu:  954  Set:  0b1110111010 Kara:  2100
# Poprzedni:  [6, 9, 5, 10, 8, 4]
# Po:  [6, 9, 5, 10, 8, 4, 2]
# Numer setu:  954  Set:  0b1110111010 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 8]
# Po:  [6, 9, 2, 5, 10, 8, 4]
# Numer setu:  955  Set:  0b1110111011 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 8, 4]
# Po:  [6, 9, 2, 5, 10, 8, 4, 1]
# Numer setu:  956  Set:  0b1110111100 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 4]
# Po:  [6, 9, 5, 10, 8, 4, 3]
# Numer setu:  957  Set:  0b1110111101 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 4, 3]
# Po:  [6, 9, 5, 10, 8, 4, 3, 1]
# Numer setu:  958  Set:  0b1110111110 Kara:  2125
# Poprzedni:  [6, 9, 5, 10, 8, 4, 3]
# Po:  [6, 9, 5, 10, 8, 4, 3, 2]
# Numer setu:  958  Set:  0b1110111110 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 8, 4]
# Po:  [6, 9, 2, 5, 10, 8, 4, 3]
# Numer setu:  959  Set:  0b1110111111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 8, 4, 3]
# Po:  [6, 9, 2, 5, 10, 8, 4, 3, 1]
# Numer setu:  960  Set:  0b1111000000 Kara:  0
# Poprzedni:  [9, 10, 8]
# Po:  [9, 10, 8, 7]
# Numer setu:  961  Set:  0b1111000001 Kara:  0
# Poprzedni:  [9, 10, 8, 7]
# Po:  [9, 10, 8, 7, 1]
# Numer setu:  962  Set:  0b1111000010 Kara:  425
# Poprzedni:  [9, 10, 8, 7]
# Po:  [9, 10, 8, 7, 2]
# Numer setu:  962  Set:  0b1111000010 Kara:  0
# Poprzedni:  [9, 10, 2, 8]
# Po:  [9, 10, 2, 8, 7]
# Numer setu:  963  Set:  0b1111000011 Kara:  0
# Poprzedni:  [9, 10, 2, 8, 7]
# Po:  [9, 10, 2, 8, 7, 1]
# Numer setu:  964  Set:  0b1111000100 Kara:  0
# Poprzedni:  [9, 10, 8, 7]
# Po:  [9, 10, 8, 7, 3]
# Numer setu:  965  Set:  0b1111000101 Kara:  0
# Poprzedni:  [9, 10, 8, 7, 3]
# Po:  [9, 10, 8, 7, 3, 1]
# Numer setu:  966  Set:  0b1111000110 Kara:  450
# Poprzedni:  [9, 10, 8, 7, 3]
# Po:  [9, 10, 8, 7, 3, 2]
# Numer setu:  966  Set:  0b1111000110 Kara:  0
# Poprzedni:  [9, 10, 2, 8, 7]
# Po:  [9, 10, 2, 8, 7, 3]
# Numer setu:  967  Set:  0b1111000111 Kara:  0
# Poprzedni:  [9, 10, 2, 8, 7, 3]
# Po:  [9, 10, 2, 8, 7, 3, 1]
# Numer setu:  968  Set:  0b1111001000 Kara:  0
# Poprzedni:  [9, 10, 8, 7]
# Po:  [9, 10, 8, 7, 4]
# Numer setu:  969  Set:  0b1111001001 Kara:  0
# Poprzedni:  [9, 10, 8, 7, 4]
# Po:  [9, 10, 8, 7, 4, 1]
# Numer setu:  970  Set:  0b1111001010 Kara:  890
# Poprzedni:  [9, 10, 8, 7, 4]
# Po:  [9, 10, 8, 7, 4, 2]
# Numer setu:  970  Set:  0b1111001010 Kara:  0
# Poprzedni:  [9, 10, 2, 8, 7]
# Po:  [9, 10, 2, 8, 7, 4]
# Numer setu:  971  Set:  0b1111001011 Kara:  0
# Poprzedni:  [9, 10, 2, 8, 7, 4]
# Po:  [9, 10, 2, 8, 7, 4, 1]
# Numer setu:  972  Set:  0b1111001100 Kara:  0
# Poprzedni:  [9, 10, 8, 7, 4]
# Po:  [9, 10, 8, 7, 4, 3]
# Numer setu:  973  Set:  0b1111001101 Kara:  0
# Poprzedni:  [9, 10, 8, 7, 4, 3]
# Po:  [9, 10, 8, 7, 4, 3, 1]
# Numer setu:  974  Set:  0b1111001110 Kara:  915
# Poprzedni:  [9, 10, 8, 7, 4, 3]
# Po:  [9, 10, 8, 7, 4, 3, 2]
# Numer setu:  974  Set:  0b1111001110 Kara:  0
# Poprzedni:  [9, 10, 2, 8, 7, 4]
# Po:  [9, 10, 2, 8, 7, 4, 3]
# Numer setu:  975  Set:  0b1111001111 Kara:  0
# Poprzedni:  [9, 10, 2, 8, 7, 4, 3]
# Po:  [9, 10, 2, 8, 7, 4, 3, 1]
# Numer setu:  976  Set:  0b1111010000 Kara:  286
# Poprzedni:  [9, 10, 8, 7]
# Po:  [9, 10, 8, 7, 5]
# Numer setu:  976  Set:  0b1111010000 Kara:  115
# Poprzedni:  [9, 5, 10, 8]
# Po:  [9, 5, 10, 8, 7]
# Numer setu:  977  Set:  0b1111010001 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 7]
# Po:  [9, 5, 10, 8, 7, 1]
# Numer setu:  978  Set:  0b1111010010 Kara:  955
# Poprzedni:  [9, 5, 10, 8, 7]
# Po:  [9, 5, 10, 8, 7, 2]
# Numer setu:  978  Set:  0b1111010010 Kara:  332
# Poprzedni:  [9, 10, 2, 8, 7]
# Po:  [9, 10, 2, 8, 7, 5]
# Numer setu:  978  Set:  0b1111010010 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8]
# Po:  [9, 5, 2, 10, 8, 7]
# Numer setu:  979  Set:  0b1111010011 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 7]
# Po:  [9, 5, 2, 10, 8, 7, 1]
# Numer setu:  980  Set:  0b1111010100 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 7]
# Po:  [9, 5, 10, 8, 7, 3]
# Numer setu:  981  Set:  0b1111010101 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 7, 3]
# Po:  [9, 5, 10, 8, 7, 3, 1]
# Numer setu:  982  Set:  0b1111010110 Kara:  980
# Poprzedni:  [9, 5, 10, 8, 7, 3]
# Po:  [9, 5, 10, 8, 7, 3, 2]
# Numer setu:  982  Set:  0b1111010110 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 7]
# Po:  [9, 5, 2, 10, 8, 7, 3]
# Numer setu:  983  Set:  0b1111010111 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 7, 3]
# Po:  [9, 5, 2, 10, 8, 7, 3, 1]
# Numer setu:  984  Set:  0b1111011000 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 7]
# Po:  [9, 5, 10, 8, 7, 4]
# Numer setu:  985  Set:  0b1111011001 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 7, 4]
# Po:  [9, 5, 10, 8, 7, 4, 1]
# Numer setu:  986  Set:  0b1111011010 Kara:  1420
# Poprzedni:  [9, 5, 10, 8, 7, 4]
# Po:  [9, 5, 10, 8, 7, 4, 2]
# Numer setu:  986  Set:  0b1111011010 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 7]
# Po:  [9, 5, 2, 10, 8, 7, 4]
# Numer setu:  987  Set:  0b1111011011 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 7, 4]
# Po:  [9, 5, 2, 10, 8, 7, 4, 1]
# Numer setu:  988  Set:  0b1111011100 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 7, 4]
# Po:  [9, 5, 10, 8, 7, 4, 3]
# Numer setu:  989  Set:  0b1111011101 Kara:  115
# Poprzedni:  [9, 5, 10, 8, 7, 4, 3]
# Po:  [9, 5, 10, 8, 7, 4, 3, 1]
# Numer setu:  990  Set:  0b1111011110 Kara:  1445
# Poprzedni:  [9, 5, 10, 8, 7, 4, 3]
# Po:  [9, 5, 10, 8, 7, 4, 3, 2]
# Numer setu:  990  Set:  0b1111011110 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 7, 4]
# Po:  [9, 5, 2, 10, 8, 7, 4, 3]
# Numer setu:  991  Set:  0b1111011111 Kara:  115
# Poprzedni:  [9, 5, 2, 10, 8, 7, 4, 3]
# Po:  [9, 5, 2, 10, 8, 7, 4, 3, 1]
# Numer setu:  992  Set:  0b1111100000 Kara:  2107
# Poprzedni:  [9, 10, 8, 7]
# Po:  [9, 10, 8, 7, 6]
# Numer setu:  992  Set:  0b1111100000 Kara:  552
# Poprzedni:  [6, 9, 10, 8]
# Po:  [6, 9, 10, 8, 7]
# Numer setu:  993  Set:  0b1111100001 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 7]
# Po:  [6, 9, 10, 8, 7, 1]
# Numer setu:  994  Set:  0b1111100010 Kara:  1242
# Poprzedni:  [6, 9, 10, 8, 7]
# Po:  [6, 9, 10, 8, 7, 2]
# Numer setu:  994  Set:  0b1111100010 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8]
# Po:  [6, 9, 2, 10, 8, 7]
# Numer setu:  995  Set:  0b1111100011 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 7]
# Po:  [6, 9, 2, 10, 8, 7, 1]
# Numer setu:  996  Set:  0b1111100100 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 7]
# Po:  [6, 9, 10, 8, 7, 3]
# Numer setu:  997  Set:  0b1111100101 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 7, 3]
# Po:  [6, 9, 10, 8, 7, 3, 1]
# Numer setu:  998  Set:  0b1111100110 Kara:  1267
# Poprzedni:  [6, 9, 10, 8, 7, 3]
# Po:  [6, 9, 10, 8, 7, 3, 2]
# Numer setu:  998  Set:  0b1111100110 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 7]
# Po:  [6, 9, 2, 10, 8, 7, 3]
# Numer setu:  999  Set:  0b1111100111 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 7, 3]
# Po:  [6, 9, 2, 10, 8, 7, 3, 1]
# Numer setu:  1000  Set:  0b1111101000 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 7]
# Po:  [6, 9, 10, 8, 7, 4]
# Numer setu:  1001  Set:  0b1111101001 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 7, 4]
# Po:  [6, 9, 10, 8, 7, 4, 1]
# Numer setu:  1002  Set:  0b1111101010 Kara:  1707
# Poprzedni:  [6, 9, 10, 8, 7, 4]
# Po:  [6, 9, 10, 8, 7, 4, 2]
# Numer setu:  1002  Set:  0b1111101010 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 7]
# Po:  [6, 9, 2, 10, 8, 7, 4]
# Numer setu:  1003  Set:  0b1111101011 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 7, 4]
# Po:  [6, 9, 2, 10, 8, 7, 4, 1]
# Numer setu:  1004  Set:  0b1111101100 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 7, 4]
# Po:  [6, 9, 10, 8, 7, 4, 3]
# Numer setu:  1005  Set:  0b1111101101 Kara:  552
# Poprzedni:  [6, 9, 10, 8, 7, 4, 3]
# Po:  [6, 9, 10, 8, 7, 4, 3, 1]
# Numer setu:  1006  Set:  0b1111101110 Kara:  1732
# Poprzedni:  [6, 9, 10, 8, 7, 4, 3]
# Po:  [6, 9, 10, 8, 7, 4, 3, 2]
# Numer setu:  1006  Set:  0b1111101110 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 7, 4]
# Po:  [6, 9, 2, 10, 8, 7, 4, 3]
# Numer setu:  1007  Set:  0b1111101111 Kara:  552
# Poprzedni:  [6, 9, 2, 10, 8, 7, 4, 3]
# Po:  [6, 9, 2, 10, 8, 7, 4, 3, 1]
# Numer setu:  1008  Set:  0b1111110000 Kara:  891
# Poprzedni:  [6, 9, 10, 8, 7]
# Po:  [6, 9, 10, 8, 7, 5]
# Numer setu:  1008  Set:  0b1111110000 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8]
# Po:  [6, 9, 5, 10, 8, 7]
# Numer setu:  1009  Set:  0b1111110001 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 7]
# Po:  [6, 9, 5, 10, 8, 7, 1]
# Numer setu:  1010  Set:  0b1111110010 Kara:  1825
# Poprzedni:  [6, 9, 5, 10, 8, 7]
# Po:  [6, 9, 5, 10, 8, 7, 2]
# Numer setu:  1010  Set:  0b1111110010 Kara:  937
# Poprzedni:  [6, 9, 2, 10, 8, 7]
# Po:  [6, 9, 2, 10, 8, 7, 5]
# Numer setu:  1010  Set:  0b1111110010 Kara:  790
# Poprzedni:  [6, 9, 2, 5, 10, 8]
# Po:  [6, 9, 2, 5, 10, 8, 7]
# Numer setu:  1010  Set:  0b1111110010 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 7]
# Po:  [6, 9, 2, 5, 10, 7, 8]
# Numer setu:  1011  Set:  0b1111110011 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 7, 8]
# Po:  [6, 9, 2, 5, 10, 7, 8, 1]
# Numer setu:  1012  Set:  0b1111110100 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 7]
# Po:  [6, 9, 5, 10, 8, 7, 3]
# Numer setu:  1013  Set:  0b1111110101 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 7, 3]
# Po:  [6, 9, 5, 10, 8, 7, 3, 1]
# Numer setu:  1014  Set:  0b1111110110 Kara:  1850
# Poprzedni:  [6, 9, 5, 10, 8, 7, 3]
# Po:  [6, 9, 5, 10, 8, 7, 3, 2]
# Numer setu:  1014  Set:  0b1111110110 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 7, 8]
# Po:  [6, 9, 2, 5, 10, 7, 8, 3]
# Numer setu:  1015  Set:  0b1111110111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 7, 8, 3]
# Po:  [6, 9, 2, 5, 10, 7, 8, 3, 1]
# Numer setu:  1016  Set:  0b1111111000 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 7]
# Po:  [6, 9, 5, 10, 8, 7, 4]
# Numer setu:  1017  Set:  0b1111111001 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 7, 4]
# Po:  [6, 9, 5, 10, 8, 7, 4, 1]
# Numer setu:  1018  Set:  0b1111111010 Kara:  2290
# Poprzedni:  [6, 9, 5, 10, 8, 7, 4]
# Po:  [6, 9, 5, 10, 8, 7, 4, 2]
# Numer setu:  1018  Set:  0b1111111010 Kara:  830
# Poprzedni:  [6, 9, 2, 5, 10, 7, 8]
# Po:  [6, 9, 2, 5, 10, 7, 8, 4]
# Numer setu:  1018  Set:  0b1111111010 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 7, 4]
# Po:  [6, 9, 2, 5, 10, 7, 4, 8]
# Numer setu:  1019  Set:  0b1111111011 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 7, 4, 8]
# Po:  [6, 9, 2, 5, 10, 7, 4, 8, 1]
# Numer setu:  1020  Set:  0b1111111100 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 7, 4]
# Po:  [6, 9, 5, 10, 8, 7, 4, 3]
# Numer setu:  1021  Set:  0b1111111101 Kara:  720
# Poprzedni:  [6, 9, 5, 10, 8, 7, 4, 3]
# Po:  [6, 9, 5, 10, 8, 7, 4, 3, 1]
# Numer setu:  1022  Set:  0b1111111110 Kara:  2315
# Poprzedni:  [6, 9, 5, 10, 8, 7, 4, 3]
# Po:  [6, 9, 5, 10, 8, 7, 4, 3, 2]
# Numer setu:  1022  Set:  0b1111111110 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 7, 4, 8]
# Po:  [6, 9, 2, 5, 10, 7, 4, 8, 3]
# Numer setu:  1023  Set:  0b1111111111 Kara:  766
# Poprzedni:  [6, 9, 2, 5, 10, 7, 4, 8, 3]
# Po:  [6, 9, 2, 5, 10, 7, 4, 8, 3, 1]

# %%
print(F[-1])
# Out:
# 766

# %%
print(ListaL[-1])
# Out:
# [6, 9, 2, 5, 10, 7, 4, 8, 3, 1]

# %%
6 9 2 5 1 3 4 7 8 10
# Out:
#   File "<ipython-input-239-05117ec39fc2>", line 1
#     6 9 2 5 1 3 4 7 8 10
#       ^
# SyntaxError: invalid syntax

# %%
bin(12)
# Out:
# '0b1100'
